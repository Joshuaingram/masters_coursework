# %%
import pymongo
import pprint
from bson.json_util import dumps, loads

client = pymongo.MongoClient("localhost",27017)

db = client.sample_airbnb
coll = db.listingsAndReviews

def show_all(cursor):
    pprint.pprint([a for a in cursor])

# %% [markdown]
# # Exercises
#
# ### mongodb.com/docs/v6.0/reference/operator/query/
#
# Exercise:
#
# - Find all of the three-bedroom listings
#     - that accommodate at least 6 people
# - And return the `name`, `bedrooms`, and `accommodates` fields.

# %% [markdown]
# Exercise:
# - Find all of the listings with TV and a Pool, but *without* internet.
# - Return the `name` and `amenities`

# %% [markdown]
# `$all` Matches arrays that contain all elements specified in the query.
# `$nin` Matches none of the values specified in an array.
#
# `$not`, `$and`, `$or`: Boolean operations

# %%
coll.find_one(
    {'$and': [
        {'bedrooms': {'$gt': 3}},
        {'bedrooms': {'$lt': 5}},
        {'amenities': {'$nin': ['Pool']}}
    ]},
    {'bedrooms', 'amenities'}
)
# Out:
# {'_id': '1155475',
#  'bedrooms': 4,
#  'amenities': ['Wifi',
#   'Air conditioning',
#   'Kitchen',
#   'Heating',
#   'Family/kid friendly',
#   'Washer',
#   'Dryer',
#   'Smoke detector',
#   'Carbon monoxide detector',
#   'Fire extinguisher',
#   'Essentials',
#   'Shampoo',
#   'Hangers',
#   'Hair dryer',
#   'Iron',
#   'Laptop friendly workspace',
#   'Self check-in',
#   'Lockbox',
#   'Private entrance',
#   'Pack ’n Play/travel crib',
#   'Bed linens',
#   'Extra pillows and blankets',
#   'Ethernet connection',
#   'Microwave',
#   'Coffee maker',
#   'Refrigerator',
#   'Dishwasher',
#   'Dishes and silverware',
#   'Cooking basics',
#   'Oven',
#   'Stove',
#   'BBQ grill',
#   'Patio or balcony',
#   'Garden or backyard',
#   'Luggage dropoff allowed',
#   'Long term stays allowed']}

# %%
coll.find_one(
    {'amenities': {'$not': {'$all': ['TV','Internet','Wifi']}}},
    {'amenities'}
)
# Out:
# {'_id': '13382536',
#  'amenities': ['TV',
#   'Cable TV',
#   'Wifi',
#   'Air conditioning',
#   'Kitchen',
#   'Free parking on premises',
#   'Elevator',
#   'Heating',
#   'Family/kid friendly',
#   'Washer',
#   'Dryer',
#   'Smoke detector',
#   'Carbon monoxide detector',
#   'First aid kit',
#   'Essentials',
#   'Shampoo',
#   'Hangers',
#   'Hair dryer',
#   'Iron',
#   'Laptop friendly workspace',
#   'Pack ’n Play/travel crib',
#   'Body soap',
#   'Bath towel',
#   'Toilet paper',
#   'Bed linens',
#   'Extra pillows and blankets',
#   'Coffee maker',
#   'Dishwasher',
#   'Oven',
#   'Smart TV',
#   'DVD player',
#   'Beach view',
#   'Rain shower',
#   'Terrace',
#   'Balcony',
#   'Sound system',
#   'Breakfast table',
#   'Espresso machine',
#   'Double oven',
#   'Murphy bed',
#   'Bedroom comforts',
#   'Bathroom essentials']}

# %%
match_comment = {'$elemMatch': {'comments': {'$regex': 'waterfront'}}};
show_all(coll.find(
    {'reviews': match_comment},
    {'reviews': match_comment, 'name': 1}
))
# Out:
# [{'_id': '10664888',
#   'name': 'PORTO DOWNTOWN FLATS-RIBEIRA STUDIO',
#   'reviews': [{'_id': '61400805',
#                'comments': 'Teresa was very welcoming and took time to explain '
#                            'whatever was necessary and answer questions about '
#                            'Porto.  The apartment was very nice - just like '
#                            'the photos.  When I mentioned that the apartment '
#                            "hadn't warmed up as much as I'd hoped, she had an "
#                            'additional heater brought by within hours.  The '
#                            'location was so easy, a block and a half from the '
#                            'waterfront restaurant scene, and almost as close '
#                            'to one of the train stations.  We were really '
#                            'happy with our stay!',
#                'date': datetime.datetime(2016, 2, 3, 5, 0),
#                'listing_id': '10664888',
#                'reviewer_id': '6129255',
#                'reviewer_name': 'Tina'}]},
#  {'_id': '10108388',
#   'name': 'Sydney Hyde Park City Apartment (checkin from 6am)',
#   'reviews': [{'_id': '408870752',
#                'comments': 'The moment you enter this Airbnb you realize this '
#                            'is a host who cares.  Chocolate on the coffee '
#                            'table, cold water in the fridge, cereal on the '
#                            'shelf, and roses in the bedroom greeted us.  Nine '
#                            'floors up you can hear the street noise but the '
#                            'bedroom is surprisingly quiet.  The location is '
#                            'near the metro and walkable to the waterfront.  '
#                            'This home and its location were perfect for our 6 '
#                            'night stay.  Would happily return on our next trip '
#                            'to Sydney.',
#                'date': datetime.datetime(2019, 2, 6, 5, 0),
#                'listing_id': '10108388',
#                'reviewer_id': '15652289',
#                'reviewer_name': 'Dave'}]},
#  {'_id': '13778742',
#   'name': 'MySweetHomePT',
#   'reviews': [{'_id': '278570170',
#                'comments': 'Alexandra’s apartment in Porto was lovely and just '
#                            'as you see in the photos. She was a knowledgeable '
#                            'and warm host offering us welcoming gifts (wine '
#                            'and fruit) and advising us on the must-see sites. '
#                            'The underground parking was a bonus. The walk to '
#                            'the old town and  the waterfront was approximately '
#                            '30 minutes but included meandering through '
#                            'charming neighbourhoods and encountering numerous '
#                            'key sites. After eating wonderful meals, we needed '
#                            'the exercise!The apartment was conveniently '
#                            'located near stops for the Hop-On, Hop-Off buses. '
#                            'We had a marvellous time discovering the delights '
#                            'of Porto and look forward to a return visit in the '
#                            'near future.',
#                'date': datetime.datetime(2018, 6, 18, 4, 0),
#                'listing_id': '13778742',
#                'reviewer_id': '69661132',
#                'reviewer_name': 'Catherine'}]},
#  {'_id': '103161',
#   'name': 'Cozy Art Top Floor Apt in PRIME Williamsburg!',
#   'reviews': [{'_id': '13343001',
#                'comments': "Adela's place was awesome.  The location could not "
#                            'be beat - close to everything in Williamsburg '
#                            'including the waterfront and both the JMZ and L '
#                            'Trains for easy access to Manhattan.  Her unit is '
#                            'decent sized and quiet.  The bed was very '
#                            'comfortable and the furniture and decorations '
#                            'nice.  It was also very clean.  While I never met '
#                            'her, check in and communication were a breeze.  We '
#                            'would not hesitate to stay at her place again.',
#                'date': datetime.datetime(2014, 5, 26, 4, 0),
#                'listing_id': '103161',
#                'reviewer_id': '676707',
#                'reviewer_name': 'D. "Rep"'}]},
#  {'_id': '1138483',
#   'name': 'Bundeena Garden Studio near beaches',
#   'reviews': [{'_id': '75972546',
#                'comments': 'Settling back into home and work after a perfect '
#                            "long weekend in Bundeena, I'm already planning a "
#                            "return trip. We'd like to thank Belinda for "
#                            'creating a beautiful self-contained studio space '
#                            'where we were able to relax, surrounded by a leafy '
#                            'garden. We felt immediately at home and had '
#                            'everything we needed to prepare and eat all of our '
#                            'meals there; and after exploring the surrounds '
#                            'during the days we were very happy to relax '
#                            'indoors in the evenings, listening to music and '
#                            'reading. The position of the studio is perfect, '
#                            'only a few minutes in either direction for a '
#                            'waterfront walk and to the local cafes and '
#                            'well-stocked IGA. We were fortunate for a late '
#                            'cancellation that we were able to book in last '
#                            'minute to the garden studio, but will be booking '
#                            'further in advance next trip to ensure '
#                            "availability in Belinda's garden studio. ",
#                'date': datetime.datetime(2016, 5, 23, 4, 0),
#                'listing_id': '1138483',
#                'reviewer_id': '72970062',
#                'reviewer_name': 'Megan'}]},
#  {'_id': '1476656',
#   'name': 'Studio + Terrace @ Historic Centre!',
#   'reviews': [{'_id': '137961032',
#                'comments': "Raul's apartment is the #1 accommodation in Porto. "
#                            'Beautifully designed, with all the amenities you '
#                            'need. Features a stunning roof-top patio that '
#                            'offers amazing views of the city. Located in a '
#                            'great neighbourhood that is close to everything: '
#                            'downtown, shopping, train and metro station, '
#                            'waterfront.\n'
#                            'Raul is the best host in Porto! We have stayed in '
#                            'his apartment 3 times now. He is super-friendly '
#                            'and welcoming and gave us lots of excellent '
#                            'suggestions for going out in Porto. Obrigado Raul!',
#                'date': datetime.datetime(2017, 3, 18, 4, 0),
#                'listing_id': '1476656',
#                'reviewer_id': '7549029',
#                'reviewer_name': 'Craig'}]},
#  {'_id': '14923016',
#   'name': 'Spacious Studio - Waimea Bay Pointe',
#   'reviews': [{'_id': '133473304',
#                'comments': 'Great location and great place to stay. When I '
#                            'booked I thought the place was directly on the '
#                            'waterfront but it was a house back but the place '
#                            'was fantastic and still had access to the ocean '
#                            'views when you walked to the front yard. Kitchen '
#                            'was good but no oven. \n'
#                            'Had a lovely stay and would definitely come back. ',
#                'date': datetime.datetime(2017, 2, 22, 5, 0),
#                'listing_id': '14923016',
#                'reviewer_id': '80171515',
#                'reviewer_name': 'Kerry'}]},
#  {'_id': '1604488',
#   'name': 'Private room with stunning view',
#   'reviews': [{'_id': '185036358',
#                'comments': 'Bernardo and Andressa are incredible hosts.  Very '
#                            'kind and laid back people who lead very '
#                            'interesting lives.  You will love talking with and '
#                            'learning from them.  The apartment itself is '
#                            'wonderful.  Very clean, spacious and '
#                            'well-decorated.  The bedroom has immediate access '
#                            'to a balcony overlooking the waterfront and you '
#                            'will have a great view of the city skyline.  '
#                            'Located near many cool spots in Brooklyn, you can '
#                            'easily walk to whatever you need.  The subway stop '
#                            'is very close too, which opens up the rest of the '
#                            'city to travelers with ease.  I would gladly stay '
#                            'here again and would recommend to anyone looking '
#                            'for an amazing place to call home for a few days.  '
#                            "Thanks y'all!",
#                'date': datetime.datetime(2017, 8, 20, 4, 0),
#                'listing_id': '1604488',
#                'reviewer_id': '2934425',
#                'reviewer_name': 'Tupelo Property Management'}]},
#  {'_id': '11447743',
#   'name': 'Apartamento São Bento da Vitória 2 - Amazing view',
#   'reviews': [{'_id': '202476067',
#                'comments': 'Staying at Rosa’s was one of the best decisions we '
#                            'made during our recent trip to Portugal! The '
#                            'apartment is fantastic, a gorgeous and spacious '
#                            'flat with tiled floors and filled with thoughtful '
#                            'amenities (coffee, fresh fruit, chocolates). The '
#                            'small balcony affords lots of light and a '
#                            'phenomenal view over the city - a great place to '
#                            'enjoy morning coffee or a nightcap. The '
#                            'convenience of the location was key, being '
#                            'situated on a quaint and quiet side street, while '
#                            'still very close to the active waterfront area as '
#                            'well as many great restaurants and bars. We felt '
#                            'so comfortable and at home here and wish we could '
#                            'have stayed longer! Check in and check out were '
#                            'very easy and Rosa and her family were kind and '
#                            'helpful. We definitely highly recommend the '
#                            'accommodations. Thanks again, Rosa!',
#                'date': datetime.datetime(2017, 10, 11, 4, 0),
#                'listing_id': '11447743',
#                'reviewer_id': '38712703',
#                'reviewer_name': 'Brendan'}]},
#  {'_id': '14164312',
#   'name': 'Waterfront Cabana',
#   'reviews': [{'_id': '104212351',
#                'comments': "Simply the best.  Our stay at Sarah and Curtis' "
#                            'waterfront cabana exceeded our every expectation.  '
#                            'It is beautiful to look at, well maintained, clean '
#                            'and so thoughtfully appointed.  The pictures look '
#                            'awesome but the cabana is even better in '
#                            'person.  \r\n'
#                            '\r\n'
#                            'Sarah has done a wonderful job equipping the '
#                            'cabana with nice things, everything you could ask '
#                            "for and so much you wouldn't even dream of asking "
#                            'for.  It was clear she worked hard to make our '
#                            'stay special.  She is very attentive while giving '
#                            'you as much or little space as you want.  She was '
#                            'very responsive and responsive both ahead of and '
#                            'during our stay.  \r\n'
#                            '\r\n'
#                            'The location is wonderful.  A quite sanctuary on '
#                            'the water.  A short drive away from the hustle and '
#                            'bustle of Waikiki beach and only a few minutes '
#                            'from excellent snorkeling, hiking, a blow hole, '
#                            'light house, beaches and more.  \r\n'
#                            '\r\n'
#                            "We're already trying to figure out when we can "
#                            'return for a longer stay in this beautiful, '
#                            "peaceful cabana.  I'll be recommending it to "
#                            'anyone who will listen.  \r\n'
#                            '\r\n'
#                            'Thank you.',
#                'date': datetime.datetime(2016, 9, 25, 4, 0),
#                'listing_id': '14164312',
#                'reviewer_id': '24260387',
#                'reviewer_name': 'Paul'}]},
#  {'_id': '17628344',
#   'name': 'Loft with balcony and view of Casa da Música PORTO',
#   'reviews': [{'_id': '327729661',
#                'comments': 'We thought the apartment was really well located '
#                            'next to Cafe de Musica and it was fairly simple to '
#                            'use the bus and metro system and also to walk!! We '
#                            'visited the historic areas as well as the '
#                            'waterfront and also Serralves (to see the gallery '
#                            'and the pink villa) and the beach at Matsinhos. '
#                            'Walking to the Jardin de palacios cristal '
#                            '(spelling?) was wonderful as it was not far and '
#                            'the gallery had an interesting exhibit and we '
#                            'liked the building’s design. Visiting the Lello '
#                            'bookstore and the landscape building near it were '
#                            'also great. The spaciousness and clean modern '
#                            'design of the apartment and the casa de musica '
#                            'plaza was a welcome contrast to the small medieval '
#                            'streets....very pleased with this selection and I '
#                            'will admit the thoughtfulness of providing some '
#                            'coffee etc was really lovely! Thanks again!',
#                'date': datetime.datetime(2018, 9, 24, 4, 0),
#                'listing_id': '17628344',
#                'reviewer_id': '99882114',
#                'reviewer_name': 'Andrea'}]},
#  {'_id': '13633280',
#   'name': 'João´s beach house',
#   'reviews': [{'_id': '148177993',
#                'comments': 'This apartment was great! It is spacious, well '
#                            'equipped and has an awesome view to the beach. '
#                            'Joao is a very helpful and very generous host. He '
#                            'communicated well and wanted to make sure we were '
#                            'comfortable. We used the bikes to ride on the '
#                            'great bike trails and waterfront. A wonderful '
#                            'location for active people!',
#                'date': datetime.datetime(2017, 4, 30, 4, 0),
#                'listing_id': '13633280',
#                'reviewer_id': '25291773',
#                'reviewer_name': 'Linda I'}]},
#  {'_id': '14921505',
#   'name': 'BEACH ESCAPE',
#   'reviews': [{'_id': '134745428',
#                'comments': 'A very large home that can genuinely handle a '
#                            'larger group. Lots of retreat areas so people can '
#                            'spread out. Location is the quintessential '
#                            'waterfront Pittwater experience. The host was good '
#                            'on the communication and any issues or advice '
#                            'quickly addressed. Highly recommend this property',
#                'date': datetime.datetime(2017, 2, 28, 5, 0),
#                'listing_id': '14921505',
#                'reviewer_id': '51677135',
#                'reviewer_name': 'Allan'}]},
#  {'_id': '13852692',
#   'name': 'VERY LARGE 5 Bedroom Home, free onsite parking',
#   'reviews': [{'_id': '110281319',
#                'comments': 'A botiuge place to stay, a little sparse in '
#                            'furnishings and would be a little cold in winter, '
#                            'lots of concrete. \r\n'
#                            'In general a nice place to stay and very '
#                            'convenient to restaurants and the city of Sydney. '
#                            'A short walk to the bottom of the hill and you are '
#                            'at the waterfront looking at the Opera House, '
#                            'Harbour Bridge and Luna Park. ',
#                'date': datetime.datetime(2016, 10, 25, 4, 0),
#                'listing_id': '13852692',
#                'reviewer_id': '85578908',
#                'reviewer_name': 'Marcus'}]},
#  {'_id': '12651199',
#   'name': 'Private apartment, small and comfortable.',
#   'reviews': [{'_id': '240629761',
#                'comments': "Leander's place is super conveniently located to "
#                            'the Rio GIG airport, and close by to the '
#                            'waterfront too, which makes for a nice morning '
#                            'walk. It was super clean, both Leander and his '
#                            'wife spoke very good English and were able to '
#                            'answer my questions and were responsive. They left '
#                            'bread, butter and water in the fridge which was '
#                            'much appreciated as I arrived late at night and '
#                            "wasn't able to buy anything. The flat is modern "
#                            'and comfortable and very well designed.',
#                'date': datetime.datetime(2018, 3, 5, 5, 0),
#                'listing_id': '12651199',
#                'reviewer_id': '38220418',
#                'reviewer_name': 'Wendy'}]},
#  {'_id': '15828858',
#   'name': 'Made4U - Glória      NEW!!!',
#   'reviews': [{'_id': '337698740',
#                'comments': 'João’s place is amazing for the price! You can '
#                            'stroll straight into the centre of Porto and even '
#                            'to the waterfront if you wish; if not, it’s '
#                            'incredibly close to the nearest Metro. João '
#                            'himself was a great host, offering us advice and '
#                            'being incredibly welcoming. The apartment itself '
#                            'is beautiful, ideally located and the bed is very '
#                            'comfortable. The only issue was the shower, which '
#                            'didn’t drain very effectively, and had to be '
#                            'managed to prevent overflowing into the bathroom. '
#                            'However, this wasn’t big enough of an issue to '
#                            'negate all of the positives of our stay! We '
#                            'couldn’t recommend João’s place any more for a '
#                            'couple looking to explore Porto!',
#                'date': datetime.datetime(2018, 10, 17, 4, 0),
#                'listing_id': '15828858',
#                'reviewer_id': '170628785',
#                'reviewer_name': 'Bethany'}]},
#  {'_id': '16262122',
#   'name': 'Lahaina Condo Near Front St. Upstairs, Corner Unit',
#   'reviews': [{'_id': '251929494',
#                'comments': "Great location!  Easy walk into downtown Lahaina's "
#                            'shops, restaurant and waterfront.  Loved the two '
#                            'pools.  Great sense of community.  Many renters '
#                            'head out for the day and come back to the pool at '
#                            'the end of the day for exchange of daily stories.  '
#                            'Loved the grounds.  Condo was clean, tidy and has '
#                            "everything you need!  Only bummer was there's no "
#                            "balcony so when you're in the condo, you're "
#                            "disconnected from outside.  But it's spacious and "
#                            'comfortably.',
#                'date': datetime.datetime(2018, 4, 8, 4, 0),
#                'listing_id': '16262122',
#                'reviewer_id': '141947214',
#                'reviewer_name': 'Sarah'}]},
#  {'_id': '12937',
#   'name': '1 Stop fr. Manhattan! Private Suite,Landmark Block',
#   'reviews': [{'_id': '41306120',
#                'comments': 'Great location close to sculpture centre and '
#                            'moma/ps1 restaurants and the gorgeous waterfront '
#                            'overlooking Manhattan which is only one subway '
#                            'stop away. Quiet room in a lovely brownstone '
#                            'street and an architect designed shower I could '
#                            'live with forever. My family of  four fitted and '
#                            'our host was a pleasure. We love the local diner '
#                            'but all kinds of dining a stroll away.  Long '
#                            'Island City is a great location from which to '
#                            'enjoy New York.',
#                'date': datetime.datetime(2015, 8, 7, 4, 0),
#                'listing_id': '12937',
#                'reviewer_id': '4586021',
#                'reviewer_name': 'Gareth'}]},
#  {'_id': '12971533',
#   'name': 'REFÚGIO BOAS VINDAS!',
#   'reviews': [{'_id': '205994681',
#                'comments': 'Silvia was such a delight! She was so informative '
#                            'and helpful with tons of options for everything we '
#                            'asked her for. She makes sure she caters to every '
#                            'type of person and is just so helpful for anything '
#                            'you can possibly ask for. Her place is SO close to '
#                            'the subway station that you can stay on to get '
#                            'into the city center. Had we known about this we '
#                            'would have utilized the subway much more! Her '
#                            'neighborhood is also very quiet and peaceful at '
#                            "night. It's the perfect place to be just off the "
#                            'beaten path but not far that a 10 minute subway '
#                            "ride can't get you to the beautiful waterfront and "
#                            'city center of Porto and a quick ride to Gaia! '
#                            'Definitely recommend this quaint private home!',
#                'date': datetime.datetime(2017, 10, 23, 4, 0),
#                'listing_id': '12971533',
#                'reviewer_id': '19354301',
#                'reviewer_name': 'Julianne'}]},
#  {'_id': '12973335',
#   'name': 'Cosy rooms close to the metro and the River',
#   'reviews': [{'_id': '91565842',
#                'comments': 'Alexia and Denis were very helpful from the '
#                            'beginning. Their house is located close to Verdun '
#                            'Metro and Wellington street so, eateries and shops '
#                            'are very close. The waterfront is about 4 blocks '
#                            'away and you can have a relaxing walk every '
#                            'evening. I wish I could have socialized more with '
#                            'Alexia and Denis. The stay was wonderful and I '
#                            'would recommend their place to my friends.',
#                'date': datetime.datetime(2016, 8, 5, 4, 0),
#                'listing_id': '12973335',
#                'reviewer_id': '42574606',
#                'reviewer_name': 'Sudharshan'}]},
#  {'_id': '16311528',
#   'name': 'New York Williamsburg empire state of mind',
#   'reviews': [{'_id': '367299821',
#                'comments': 'BEST AIR BNB EVER!! Wow, this place was more than '
#                            'I was hoping for. Amazing views, surround sound '
#                            'Bluetooth speakers, huge bed, big windows, rooftop '
#                            'patio, modern features... this place has it all. '
#                            'The area was perfect, super chill but enough going '
#                            'on to feel like New York. Great coffee shops on '
#                            'and around the block, easy to find parking, and '
#                            'close walk to the waterfront. The value for this '
#                            'place is amazing, I will 10000% be coming back.',
#                'date': datetime.datetime(2019, 1, 4, 5, 0),
#                'listing_id': '16311528',
#                'reviewer_id': '126151987',
#                'reviewer_name': 'Bailey'}]},
#  {'_id': '1310308',
#   'name': 'Mosman Apartment',
#   'reviews': [{'_id': '219567501',
#                'comments': "Mags' Mosman home is absolutely gorgeous. As a "
#                            'family of three is had everything we could '
#                            'possibly need. We were very comfortable and really '
#                            'settled in for a few months. This place is really '
#                            'more equipped for shortterm stays however.\n'
#                            '\n'
#                            'The big, soaking tub was really lovely and the '
#                            'leafy, breezy outlet was beautiful. The proximity '
#                            'to the local shops, park and waterfront at Mosman '
#                            'Bay made life really easy. The ferry wharves '
#                            'nearby were easy to walk to and connections very '
#                            'frequent for Sydney. The bus was harder to get- '
#                            'but by no means impossible.\n'
#                            '\n'
#                            'Balmoral beach is very close and we spent lots of '
#                            'time there. The bus stop to get the bus to the '
#                            'beach is a fair walk away- but worth it to avoid '
#                            'the nightmare parking situation in summer! Mind '
#                            "you- the drive isn't far at all, so if you get "
#                            'lucky that is the easiest option.\n'
#                            '\n'
#                            'The walk down to Sirius Cove dog beach is lovely '
#                            'and the swimming there is not bad either. You can '
#                            'continue your walk along the headline all the way '
#                            'around to Athol Bay for even better swimming or '
#                            'Taronga Zoo entry.\n'
#                            '\n'
#                            'We only had trouble finding a street parking spot '
#                            'maybe twice in almost three months- so that was '
#                            "pretty manageable I'd say.\n"
#                            '\n'
#                            'The Orpheum Theatre is delightful and the shopping '
#                            'on Military Road east was great.\n'
#                            '\n'
#                            'Beware there is no wifi, microwave or toaster! '
#                            "It's a bit like taking a step back in time. But we "
#                            'loved it all the same.',
#                'date': datetime.datetime(2017, 12, 18, 5, 0),
#                'listing_id': '1310308',
#                'reviewer_id': '16597293',
#                'reviewer_name': 'Ingrid'}]},
#  {'_id': '16467953',
#   'name': 'crowntown apartment 2b',
#   'reviews': [{'_id': '234577455',
#                'comments': 'Nice clean flat that is both really easy to get to '
#                            'from the airport and is within walking distance of '
#                            'the central waterfront. Diego was really helpful '
#                            'giving us tips of where to eat and also helped '
#                            'organise a tour around one of the port houses. '
#                            'Highly recommended!',
#                'date': datetime.datetime(2018, 2, 13, 5, 0),
#                'listing_id': '16467953',
#                'reviewer_id': '3052788',
#                'reviewer_name': 'Tom'}]},
#  {'_id': '19319',
#   'name': 'Private room Great Deal at Lower East Side',
#   'reviews': [{'_id': '606236',
#                'comments': 'This is as good as it gets!  This is my first '
#                            'experience with the airbnb.com community.  I have '
#                            'been blown away by the quality of the service and '
#                            'level of communication from both the '
#                            'administrative side and by my hostess, Ana. Ana '
#                            'and Kathie were both very responsive to my emails '
#                            'before my arrival to NY.  We arrived early before '
#                            'they got off work, but Ana got her girlfriend to '
#                            'come over to open the door for us. Their apartment '
#                            'is in a secured building located in a safe '
#                            'neighborhood with a great view of the waterfront '
#                            'and bridges.  The room was comfortable with a/c. '
#                            'Their location is so convenient to getting around '
#                            'Manhattan either by subway or walking.\r\n'
#                            'Ana is a great person. She loves sharing her '
#                            'favorite places and eating hang-outs.  She had '
#                            'very good non-touristy recommendations.  She '
#                            'always was available to us if any questions or '
#                            'issues arose.  Don’t ever hesitate to rent from '
#                            'Ana and Kathie!  If I am in NY again, I would do '
#                            'it again in a heartbeat!\r\n'
#                            'Even the airbnb.com administrative contacts were '
#                            'great.  I had a billing issue that I called in the '
#                            'middle of the evening and they had someone resolve '
#                            'it immediately!  That’s impressive!\r\n',
#                'date': datetime.datetime(2011, 10, 7, 4, 0),
#                'listing_id': '19319',
#                'reviewer_id': '1111262',
#                'reviewer_name': 'Raymond'}]},
#  {'_id': '1936633',
#   'name': 'Great 1BD waterfront City Island NY',
#   'reviews': [{'_id': '11531185',
#                'comments': 'Didier and I spent a perfect two weeks at Alex and '
#                            "Noelva's wonderful apartment.  It's cozy, very "
#                            'well appointed, quiet and decorated creatively.  '
#                            'The waterfront location is beautiful and very '
#                            'convenient to everything on City Island but also '
#                            'tucked away so as to feel very private.  Alex and '
#                            'Noelva are amazing people and we feel we have made '
#                            'new friends and will most definitely be back.  '
#                            'Also, an awesome HD TV and fully equipped kitchen '
#                            'even made staying home on a rainy day a great '
#                            'experience.  We just got back and we miss you '
#                            'already!  Merci beaucoup, gros bisous, Linda & '
#                            'Didier',
#                'date': datetime.datetime(2014, 4, 7, 4, 0),
#                'listing_id': '1936633',
#                'reviewer_id': '119445',
#                'reviewer_name': 'Linda & Didier'}]},
#  {'_id': '15498188',
#   'name': 'FloresRooms Mouzinho 2',
#   'reviews': [{'_id': '176053742',
#                'comments': 'The location could not be better.  Central to the '
#                            'train station, bus stops, waterfront and all key '
#                            'neighbourhoods. The juliet balconies add beauty '
#                            'and breeze to the apartment. Highly recommend!',
#                'date': datetime.datetime(2017, 7, 30, 4, 0),
#                'listing_id': '15498188',
#                'reviewer_id': '62470623',
#                'reviewer_name': 'Jenny'}]},
#  {'_id': '1584102',
#   'name': 'Sydney beachside apt',
#   'reviews': [{'_id': '40713982',
#                'comments': 'This is really an Ideal home away from home. The '
#                            'apartment is just by the bay and offers great '
#                            'waterfront views. Fred and Benedette are amazing '
#                            'hosts, and in addition to providing excellent '
#                            'suggestions, provided a dossier  which had very '
#                            'useful tips on things to see how to get around. '
#                            'The house itself is a 2 bedroom apartment with the '
#                            'second bedroom facing the waterfront, and '
#                            "furnished with a pull out sofa bed. It's in "
#                            'pristine condition, exceptionally clean and very '
#                            'family-friendly. My two kids both under five years '
#                            'old slept all through the night so I know the were '
#                            'comfortable. Ideal location for a quiet stress '
#                            'free holiday.',
#                'date': datetime.datetime(2015, 8, 2, 4, 0),
#                'listing_id': '1584102',
#                'reviewer_id': '20340604',
#                'reviewer_name': 'Godwin'}]},
#  {'_id': '16078811',
#   'name': 'Oceanfront & Breath Taking Views.',
#   'reviews': [{'_id': '320411224',
#                'comments': 'The place is conveniently located in Kaanapali '
#                            'area - close to many beaches within 15 min driving '
#                            'distances. Amazing sunset view from the lanai is '
#                            'priceless. Be aware that the access to the '
#                            'waterfront/beach is closed due to construction. \n'
#                            '\n'
#                            'We had some issues with the cleanness of the house '
#                            'and ended up buying wet Swiffer ourselves and '
#                            'clean the floor and some other kitchen amenities '
#                            "that wasn't fully clean when we arrived. \n"
#                            '\n'
#                            'Hot shower was also not working for multiple '
#                            'times, and there are several occasions (at least '
#                            'we know of )that all electricity got shut off (up '
#                            'to 15 min each or so each time), which probably '
#                            'ruined some food in the refrigerator. This might '
#                            "be beyond the owner's control, but something we "
#                            'noticed while we were there.\n'
#                            '\n'
#                            "Overall, we enjoyed our stay in Francesco's place "
#                            "- can't beat the location.",
#                'date': datetime.datetime(2018, 9, 8, 4, 0),
#                'listing_id': '16078811',
#                'reviewer_id': '13416808',
#                'reviewer_name': 'Aya'}]},
#  {'_id': '21662064',
#   'name': 'THE DOURO WINDOW',
#   'reviews': [{'_id': '265837415',
#                'comments': 'This unit is just gorgeous, perched on top of an '
#                            'old warehouse with incredible river and city '
#                            'views. It is about a 15 minute walk around to all '
#                            'the waterfront hub and port caves. It’s a nice '
#                            'riverside walk, flat and it’s good to escape the '
#                            'crowds.  Would stay again in a heartbeat.',
#                'date': datetime.datetime(2018, 5, 18, 4, 0),
#                'listing_id': '21662064',
#                'reviewer_id': '2108096',
#                'reviewer_name': 'Jackie'}]},
#  {'_id': '21946009',
#   'name': 'Mid Century Modern Guesthouse with Pool and Views!',
#   'reviews': [{'_id': '329423564',
#                'comments': 'Great spot with a view of the Hilo waterfront.  '
#                            'Quiet area but only a few minute drive to '
#                            'downtown.  Would stay again!',
#                'date': datetime.datetime(2018, 9, 28, 4, 0),
#                'listing_id': '21946009',
#                'reviewer_id': '18513712',
#                'reviewer_name': 'Brad And Katy'}]},
#  {'_id': '23828577',
#   'name': 'Hawaii Is Calling You!! Answer the Call!!',
#   'reviews': [{'_id': '260411556',
#                'comments': 'I had a wonderful stay at Edna’s during my trip to '
#                            'Kona! This charming unit is very clean, cozy, '
#                            'comfortable, and short stroll to downtown '
#                            'beachfront. \n'
#                            'There’s a gate from the complex that leads '
#                            'directly to Ali’i Dr, where all the shops, cafes '
#                            'and restaurants are. I love how central the '
#                            'location is and within 5minutes I’m at the beach '
#                            'for a swim, or getting a massage right across the '
#                            'street (Theresa is amazing at Ka Lima Hana '
#                            'Kukui!)   The farmers market is also next door on '
#                            'Wed/Thurs, where you can buy fresh fruit and '
#                            'coffee to take back home! There is a coffee pot '
#                            'with filters so you can brew your very own Kona '
#                            'coffee to enjoy every morning! \n'
#                            '\n'
#                            'There’s also a patio outside with relaxing and '
#                            'quaint poolside/garden views. All the towels and '
#                            'linens very clean and fresh, the bed was plush, '
#                            'cozy and very comfortable- a real “home away from '
#                            'home.” There is a nice AC in the unit so you feel '
#                            'refreshed after the hot tropical weather! My '
#                            'friend came over to enjoy it as well, as where she '
#                            'was staying, her place did not have AC- it makes a '
#                            'big difference! \n'
#                            '\n'
#                            'The hot shower/water pressure is also great in the '
#                            'unit and replenished me after several days of '
#                            'scuba diving trips. I went with Jack’s Diving '
#                            'Locker in the complex next door (super convenient '
#                            'and their charter is one of the best on the '
#                            'island- check out their reviews on Yelp) The first '
#                            'evening we ate at Huggo’s just a short stroll by '
#                            'the waterfront. Delicious food, beautiful view and '
#                            'great service! \n'
#                            '\n'
#                            'I received a very warm, courteous and clear '
#                            'communication from Jeanette, with very easy '
#                            'check-in and out. I could not have asked for a '
#                            'better, more comfortable location to stay in Kona! '
#                            'I’ll definitely come back and stay again! Mahalo! ',
#                'date': datetime.datetime(2018, 5, 4, 4, 0),
#                'listing_id': '23828577',
#                'reviewer_id': '438462',
#                'reviewer_name': 'Kelly'}]},
#  {'_id': '25701117',
#   'name': 'House General Torres',
#   'reviews': [{'_id': '343692997',
#                'comments': 'Pedro’s place is fantastic, completley renewed and '
#                            'stylish. He was a good host, and did not bother '
#                            'us. We are a family of 4 and would be happy zo '
#                            'have more glasses and plates. The views and the '
#                            'location of the apartment is fantastic, the metro '
#                            'is close as well as the waterfront! We would '
#                            'definetly come again!',
#                'date': datetime.datetime(2018, 11, 1, 4, 0),
#                'listing_id': '25701117',
#                'reviewer_id': '86117424',
#                'reviewer_name': 'Spela'}]},
#  {'_id': '17960308',
#   'name': 'Magic Escape Apartments 3 - Douro River Views',
#   'reviews': [{'_id': '298322307',
#                'comments': 'This spot is 5* and more and Diogo and Jose were '
#                            'amazing hosts! The pictures don’t do justice to '
#                            'how fantastic it is! It is large and very very '
#                            'clean with special touches throughout the '
#                            'apartment. From the pasteis de nata and port wine '
#                            'to welcome us to the clothes pins to a rack to '
#                            'hang dry your clothes on the hosts have thought of '
#                            'every detail. The place was large and spacious for '
#                            'our family and the kids loved it! The view is '
#                            'again way way better than the pictures show and '
#                            'it’s location on this side of the river with steps '
#                            'down to the waterfront and port caves is just '
#                            'perfect. Thank you again for an amazing stay!',
#                'date': datetime.datetime(2018, 7, 29, 4, 0),
#                'listing_id': '17960308',
#                'reviewer_id': '49597708',
#                'reviewer_name': 'Minakshi'}]},
#  {'_id': '2422745',
#   'name': 'So close of tourist attractions :)',
#   'reviews': [{'_id': '26747119',
#                'comments': "We stayed at Monica's apartment during Carnival "
#                            '2015. We highly recommend staying with her. Our '
#                            'room was big, clean, had air conditioning, a '
#                            'private washroom, constant wifi and filtered water '
#                            'to drink. Her apartment is centrally located to '
#                            'all attractions. A 10 min walk to lapa. 10 min to '
#                            'the waterfront. I always felt safe in her '
#                            'neighbourhood. As a host, she is a warm and caring '
#                            'person. She invited us out to a bloco party the '
#                            'first night, guided us to the Sambodromo, took us '
#                            'to a street market and MAM. She even helped us '
#                            'coordinate future accommodations and '
#                            'transportation. Although we had a language '
#                            'barrier, communication was not a problem. Thank '
#                            'you Monica!',
#                'date': datetime.datetime(2015, 2, 18, 5, 0),
#                'listing_id': '2422745',
#                'reviewer_id': '26051728',
#                'reviewer_name': 'H'}]},
#  {'_id': '248537',
#   'name': 'Apartamento de Qualidade no Porto',
#   'reviews': [{'_id': '1174950',
#                'comments': 'The apartment was fully furnished - groceries and '
#                            'all.  The parking was perfect and safe inside the '
#                            'back yard.  The furnishings were top of the line, '
#                            'and functioning perfect.  Carlos greeted us in '
#                            'person, even though we revived a little late.  He '
#                            'brought a jar of fig jam to welcome us to Porto.  '
#                            'He gave us lots of tips and directions.  The '
#                            'apartment is not within but within walking '
#                            'distance of the very center of Porto and the '
#                            'waterfront.  We could hear some noise from the '
#                            'street overnight but manageable.  We would '
#                            "recommend Carlos's apartment and Carlos as a host "
#                            'anytime.',
#                'date': datetime.datetime(2012, 4, 24, 4, 0),
#                'listing_id': '248537',
#                'reviewer_id': '436156',
#                'reviewer_name': 'Ali'}]},
#  {'_id': '28148913',
#   'name': 'Gorgeous Hawaiian Views 1 Bedroom Apt',
#   'reviews': [{'_id': '324791818',
#                'comments': 'A nice spacious place for 2 people, quite private '
#                            "with amazing views of the Ko'olau mountains. No "
#                            'water views, but the mountain view is actually '
#                            'better seeing the changing light on the ridges. '
#                            'The place has all amenities for a short or longer '
#                            "stay including a generous deck we didn't have much "
#                            "time to use. It's clean and not overly decorated, "
#                            "which suited us fine. It's easy to find and get in "
#                            'and out of with Likelike, Pali Hwy and H3 all '
#                            "nearby. Thus, it's conveniently located to get to "
#                            'the North, South and West side of the island while '
#                            'being in a not so touristy low-key spot. Having '
#                            'lived in the area before, we found Kaneohe little '
#                            'changed in regards to restaurants and cafes, a bit '
#                            'unexciting. However, Kailua has some good gems for '
#                            "eating, coffee and small store shopping and it's "
#                            'just a quick 10-minute drive away. So is one of '
#                            'the best beaches on the island, so all in one spot '
#                            'if you want it. Why not stay in Kailua then? '
#                            'Unless you are waterfront, the views can leave you '
#                            'a bit wishing. And yes, there is a rooster that '
#                            "crows early in the morning. However, we didn't "
#                            'find it to be a problem and went right back to '
#                            'sleep. Just makes things feel a bit more local, '
#                            'the whole reason to stay in an AirBnB. Mahalo!',
#                'date': datetime.datetime(2018, 9, 17, 4, 0),
#                'listing_id': '28148913',
#                'reviewer_id': '23740864',
#                'reviewer_name': 'Steve & Kirsti'}]},
#  {'_id': '28660186',
#   'name': "Suite privée a  10 min de l'aéroport",
#   'reviews': [{'_id': '330515859',
#                'comments': 'Marie-Jose and Jacques were superb hosts! '
#                            'Marie-Jose responded to all my inquiries very '
#                            'promptly prior to my stay. I loved that they were '
#                            'so flexible and accommodating with the check-in '
#                            'and check-out times as this greatly helped with '
#                            'our travel plans. \n'
#                            '\n'
#                            'Their place is conveniently located in Lasalle '
# ...
#                            'accommodate two couples with a child apiece. Also, '
#                            'it does come with a single car enclosed garage, so '
#                            'parking is not an issue. The soaring ceilings and '
#                            'comfy furniture (good stuff, not your typical '
#                            'cheap hotel furniture) are perfect for coaxing you '
#                            'into laying around and relaxing rather than '
#                            'heading out for activities. The whole place - from '
#                            'the appliances to the decor - just exudes a '
#                            'feeling of luxury and class that you rarely get in '
#                            "the typical vacation rental. I've definitely paid "
#                            'a lot more for a lot less. The outdoor grill and '
#                            'patio are so great for cooking, dining and '
#                            'post-meal lounging that we ended up just sticking '
#                            'around there for most meals rather than eating '
#                            'out. \r\n'
#                            '\r\n'
#                            'The resort grounds are very well maintained, and '
#                            'the pool area included a large kiddie pool that '
#                            'was only about 1 foot deep - perfect for our '
#                            'little ones. After experiencing the nonstop '
#                            'crushing crowds everywhere you go on Oahu, it was '
#                            'surprising how quiet and uncrowded this place was '
#                            '- even on a spring break week. If pools and '
#                            "jacuzzis aren't your thing, a few minutes drive "
#                            'gets you to the Mauna Lani beach club. There are '
#                            'lots of cabanas and lounge chairs to use, but get '
#                            'there early as the cabanas were full by 9am and '
#                            'the chairs by 10am. The condo also comes with '
#                            'plenty of beach chairs, so you can always bring '
#                            'those and skip the cabana hunt. The snorkeling was '
#                            'superb, and there are many beautiful paths '
#                            'meandering along the waterfront. Up and to the '
#                            'left were a few benches along the golf course for '
#                            'whale watching, while to the right were fishponds '
#                            'and several spots with lounge chairs tucked under '
#                            'palm trees. I highly recommend grabbing a book and '
#                            'a drink and hunting down one of these spots.\r\n'
#                            '\r\n'
#                            'Lastly, the golf course. We played Mauna Lani '
#                            'South, and it was a good as advertised. The course '
#                            'is in great shape, and the views are stunning '
#                            'enough to help you forget all the balls you left '
#                            'in the lava rocks. \r\n'
#                            '\r\n'
#                            'I highly recommend this place, and we will be '
#                            'coming back!',
#                'date': datetime.datetime(2015, 3, 23, 4, 0),
#                'listing_id': '4840020',
#                'reviewer_id': '27572028',
#                'reviewer_name': 'Dalen'}]},
#  {'_id': '9701620',
#   'name': 'Glebe Treetop Cottage. Just 200m to Sydney Harbour',
#   'reviews': [{'_id': '61396027',
#                'comments': 'My husband, baby and I had a wonderful time '
#                            'staying at the cottage. All the baby equipment at '
#                            'the cottage really made our stay so much easier. '
#                            'We loved the easy access to restaurants and often '
#                            'strolled around the waterfront and darling '
#                            'harbor.  Bryan and his daughter are such great '
#                            'hosts! ',
#                'date': datetime.datetime(2016, 2, 3, 5, 0),
#                'listing_id': '9701620',
#                'reviewer_id': '1855647',
#                'reviewer_name': 'Yas & Andrew'}]},
#  {'_id': '9802077',
#   'name': 'Sydney Studio in Glebe Close to CBD. SparklinClean',
#   'reviews': [{'_id': '90351293',
#                'comments': 'Helena is a charming host, who met me to hand over '
#                            'the keys and show me the unit. \r\n'
#                            'The studio is bright and compact with a well '
#                            'equipped kitchen, and a comfortable bed. The '
#                            'balcony has a great view!\r\n'
#                            'This is a quiet neighbourhood, only a short walk '
#                            'to shops, cafes and transport.\r\n'
#                            'The waterfront walk to Rozelle or the Fish markets '
#                            'is a bonus.',
#                'date': datetime.datetime(2016, 7, 31, 4, 0),
#                'listing_id': '9802077',
#                'reviewer_id': '82823812',
#                'reviewer_name': 'Toni'}]},
#  {'_id': '4164487',
#   'name': "Oh this one's lovely... and cheap!",
#   'reviews': [{'_id': '280686703',
#                'comments': "Duncan and Ashlee's flat is in a lovely area of "
#                            'Sydney.  It is close to some lovely parklands '
#                            'going down to the waterfront, near the shops at '
#                            'Rozelle, the amazing Orange Grove market on a '
#                            'Saturday and has good links into the City Centre.  '
#                            'The room for one or two people is of a good size, '
#                            'the bed is comfy and the whole flat spotlessly '
#                            'tidy and clean.  I thoroughly recommend Duncan and '
#                            'Ashlee - they are great hosts.  ',
#                'date': datetime.datetime(2018, 6, 23, 4, 0),
#                'listing_id': '4164487',
#                'reviewer_id': '37974571',
#                'reviewer_name': 'Lindsay'}]},
#  {'_id': '6868273',
#   'name': 'Casa da Hera - The Ivy House',
#   'reviews': [{'_id': '90009900',
#                'comments': 'Carlos was very responsive upon booking. He had a '
#                            'relative meet us, she was very nice. We felt '
#                            'terrible as we got lost on our way and she waited '
#                            'for over an hour for us! They had plenty of coffee '
#                            'and the wifi worked well. There is the most '
#                            'delicious restaurant/cafe right downstairs, '
#                            'nothing fancy but the food is incredible. The home '
#                            'was great, very nicely taken care of. The location '
#                            "couldn't be better! You can walk right out your "
#                            'door and be to the waterfront in 5 min. If you go '
#                            'in the summer keep in mind that there is no air '
#                            'conditioning so it was extremely hot. We did a day '
#                            'tour to the Duoro Wine region which was beautiful '
#                            'and the port was delicious. I would absolutely '
#                            'stay here again. ',
#                'date': datetime.datetime(2016, 7, 30, 4, 0),
#                'listing_id': '6868273',
#                'reviewer_id': '6311220',
#                'reviewer_name': 'Karin'}]},
#  {'_id': '8809414',
#   'name': 'Kona Kondo I- beautiful oceanfront Casa de Emdeko',
#   'reviews': [{'_id': '275801241',
#                'comments': 'This location is very convenient and the '
#                            'waterfront waves were the highlight. We had quite '
#                            'a few lovely mornings and sunsets watching and '
#                            'listening to the waves crash against the rocky '
#                            'shore. The sandy beach lounge area is a really '
#                            'nice touch, as well as the salt water pool, '
#                            'because you get all the beauty vibes even not '
#                            'being in an ocean-front swimmable location. \n'
#                            'The main drag of Kona is an easy 15m walk away, or '
#                            'you can hop on the trolley. We seemed to keep '
#                            'missing the trolley so we hitchhiked or walked to '
#                            'town most days. I recommend renting a car to enjoy '
#                            'the island, unless you are an ambitious hitchhiker '
#                            '(which is quite safe on the island). This unit '
#                            'comes with a parking pass which was really nice. \n'
#                            'The day we arrived there was a notice on the unit '
#                            'that the electricity would be out from 7am-7pm the '
#                            'next day, so neither the unit electric amenities '
#                            'or the pools were open. We rearranged our plans to '
#                            'be gone that day, but as a very-much-not morning '
#                            'person, the immediate early wake up to be able to '
#                            'shower and whatnot right after a long day of '
#                            'travel was kind of a bummer. The host gave us a '
#                            'partial refund for this day after some back and '
#                            'forth. \n'
#                            'If you are squeamish about bugs, be prepared to '
#                            'spot a cockroach or two. There was a huge dead one '
#                            'when we arrived and some smaller ones we got rid '
#                            'of. I think that because this is a ground level '
#                            'unit off the garden area, they sneak in the lanai '
#                            "door when left open. Wasn't a huge deal to us. \n"
#                            'The premises are really lovely and well kept. Take '
#                            "a peek in the bush on the lanai and you'll spot a "
#                            'bird nest! there were two eggs there during our '
#                            'trip so the next guests may have some chicks to '
#                            'admire. \n'
#                            'The neighbors and other guests are really kind as '
#                            'well. One couple feeds wild eels that live in the '
#                            "rocks. I'd never seen wild eels so that was a "
#                            'really neat thing to see. \n'
#                            'Overall a good trip, with just a couple minor '
#                            'hiccups!',
#                'date': datetime.datetime(2018, 6, 11, 4, 0),
#                'listing_id': '8809414',
#                'reviewer_id': '15649608',
#                'reviewer_name': 'Jenette'}]},
#  {'_id': '4957358',
#   'name': 'A Romantic Loft plus terrace  Heart of Brooklyn',
#   'reviews': [{'_id': '54368291',
#                'comments': 'Amy was the best host you can ask for and you can '
#                            "definitely expect we'll be coming back. If you're "
#                            "staying in Brooklyn, it doesn't get better than "
#                            'this. My Fiance and I did our engagement session '
#                            'and Amy let us start at hour loft, the place was '
#                            'perfect for a romantic session and only a few '
#                            'stops from the waterfront where we finished our '
#                            "session. Can't rave about this place enough! Thank "
#                            'you again Amy and see you in the future!',
#                'date': datetime.datetime(2015, 11, 19, 5, 0),
#                'listing_id': '4957358',
#                'reviewer_id': '26612912',
#                'reviewer_name': 'John'}]},
#  {'_id': '5581269',
#   'name': 'Backyard cabin by lovely Pittwater',
#   'reviews': [{'_id': '109303612',
#                'comments': 'Beautiful secluded cabin, the perfect space to '
#                            'relax and unwind, just a short walk from '
#                            "clareville reserve, one of Sydney's most stunning "
#                            'waterfronts. Michy is the pe',
#                'date': datetime.datetime(2016, 10, 20, 4, 0),
#                'listing_id': '5581269',
#                'reviewer_id': '4257407',
#                'reviewer_name': 'Niamh'}]},
#  {'_id': '6670684',
#   'name': 'Luxury condo, near the water, with garage',
#   'reviews': [{'_id': '165338039',
#                'comments': 'Our first time to Montreal. The location was '
#                            'great, walkable to old town and the metro in a '
#                            'quiet area near the waterfront. Apartment was '
#                            'large for a one bedroom and well appointed. '
#                            'Jonathon was a fantastic host who left us a bottle '
#                            'of bubbly and fresh bread to welcome us to '
#                            'Montreal. He was very flexible with the check-in '
#                            'and brought over a hairdryer when we realized we '
#                            "didn't have one. Would not hesitate to stay here "
#                            'again on our next visit to this lovely city. ',
#                'date': datetime.datetime(2017, 7, 1, 4, 0),
#                'listing_id': '6670684',
#                'reviewer_id': '124500087',
#                'reviewer_name': 'Martin'}]},
#  {'_id': '8426566',
#   'name': 'Kailua Kona Village Breeze Condo',
#   'reviews': [{'_id': '64438421',
#                'comments': "I had a very comfortable stay in Alethea's place; "
#                            'it was really well-equipped for all my needs.  '
#                            'Strong wifi, comfy bed, a great shower, a good '
#                            'kitchen, beach towels,  a balcony to enjoy my '
#                            "morning coffee, and my own parking spot.  It's "
#                            'just a short walk to the village/waterfront shops '
#                            'and restaurants, too. ',
#                'date': datetime.datetime(2016, 3, 4, 5, 0),
#                'listing_id': '8426566',
#                'reviewer_id': '11771485',
#                'reviewer_name': 'Heather'}]},
#  {'_id': '941361',
#   'name': 'Hale Kea - A Relaxing Apartment with Ocean Views in Kona',
#   'reviews': [{'_id': '210329543',
#                'comments': 'This place is very close to downtown. Lanai has a '
#                            'great view facing the waterfront. They also had '
#                            'guidebooks that helped us plan our time here. The '
#                            'host provided us Snorkeling goggles and tubes. '
#                            'This place is close to Kahuluu which is super '
#                            'great for Snorkeling. Mauna Kea beach and Honaunau '
#                            "is also very close by and it's very good for "
#                            'Snorkeling. All the amenities are super new and '
#                            'modern (really cool shower).\n'
#                            '\n'
#                            'Their guidebooks also had suggestions for '
#                            'breakfast. We found that helpful as well. Try out '
#                            'Daylightmind Cafe.\n'
#                            '\n'
#                            'We are definitely stay here when we come back!',
#                'date': datetime.datetime(2017, 11, 8, 5, 0),
#                'listing_id': '941361',
#                'reviewer_id': '15201046',
#                'reviewer_name': 'Karthik'}]}]

# %%
coll.find_one(
    {'bedrooms': 2},
    {'reviews','host.host_name', 'name'}
)
# SELECT host.host_name, name FROM coll WHERE bedrooms=2;
# Out:
# {'_id': '13382536',
#  'name': 'Modern Beachside Apartment with Balcony',
#  'host': {'host_name': 'David'},
#  'reviews': [{'_id': '140499497',
#    'date': datetime.datetime(2017, 3, 30, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '117161775',
#    'reviewer_name': 'Darmo',
#    'comments': "David's large, modern, cozy, clean and comfortable apartment is located in the newer section of Barcelona, in a quiet neighbourhood. The large underground parking is well lit, clean and roomy making manouvering our car very easy. It has direct elevator access to the apartment above, so unloading and loading the car was very convenient.\n\nThe area around the apartment has stores, restaurants, a Mercadona Supermarket, and many smaller grocery stores. The sidewalks are broad and evenly graded which makes for easy walking, and clean.\n\nPublic buses are frequent and easy to use, and there is an underground Metro station nearby within easy walking distance.\n\nDavid was what I would call a super host. His apartment was well equipped with every modern convenience and very clean. It was also very well stocked with food; bread, milk, juice, fresh fruit, butter, coking oil, etc., including a bottle of wine.\n\nHe patiently and carefully explained the works of every appliance in the apartment, including the use of the television features, and he made sure you are aware that he is available for any question later on. Communicating in English was not a problem.\n\nWe greatly appreciated the considerable time he spent providing us with detailed explanation of all the major attractions of Barcelona and how to get there. His Guest Guidebook includes all the details one could possibly ever need while in Barcelona, from managing emergency situations, using public transport, maps, to restaurants, shops, museums and all major attractions. Our visit to Barcelona was made much easier because of the book, and we learned a lot more.\n\nWe would recommend anyone visiting Barcelona to use David's place. We will definitely return to David's apartment if we should want to visit Barcelona again. The five days we were there were not enough.\n"},
#   {'_id': '141094212',
#    'date': datetime.datetime(2017, 4, 2, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '84315133',
#    'reviewer_name': 'Samuel',
#    'comments': "David a un accueil convivial et très précis avec toutes les informations dont vous avez besoins.L'appartement est bien placé, agréable et chaleureux.Nous y retournerons sans hésiter."},
#   {'_id': '142777648',
#    'date': datetime.datetime(2017, 4, 9, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '74509541',
#    'reviewer_name': 'Laurie',
#    'comments': "Nous avons passé un agréable séjour dans l'appartement de David. Il est très bien aménagé et confortable. L'appartement se situe à environ 20 minutes à pied de bars et discothèques pour sortir le soir et proche des transports en commun pour rejoindre le centre-ville. \nL'appartement est très propre et bien équipé (serviettes, plaids, petit déjeuner, savon, etc.)\nDavid nous a donné beaucoup d'informations (attention à ne pas être trop long ;-) ) pour se restaurer (très bonnes adresses), visiter et sortir!\nJe recommande cet appartement. "},
#   {'_id': '168800892',
#    'date': datetime.datetime(2017, 7, 10, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '43538795',
#    'reviewer_name': 'Valentina',
#    'comments': 'Nuestra estadía de 16 días en el departamento de David fue fabulosa. El departamento era espectacular y limpio, con una muy buena ubicación en una zona moderna y silenciosa de Barcelona. \nDavid es gentil, empático, correcto y por sobretodo, amable. Siempre disponible 24 horas ante cualquier duda o circunstancia. Nos recibió con comida, vino y muchos otros artefactos que fueron indispensables en nuestra estadía allí (shampoo, pasta de dientes, elementos de limpieza). No solo eso sino que también, se tomó el tiempo para explicarnos los lugares que no nos podíamos perder, y los restaurantes a cuales ir.  Fue un placer para nosotros poder conocerlo, y estamos seguros que en nuestros próximos viajes a Barcelona, contactar a David será nuestra primera opción. \n\nEn fin, nuestra estadía en Barcelona fue asombrosa, y gran parte fue gracias a David. Nos hizo sentir en casa. Muchas gracias!!'},
#   {'_id': '170259120',
#    'date': datetime.datetime(2017, 7, 15, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '134589877',
#    'reviewer_name': 'Samuele',
#    'comments': 'Excelente todo!! David además es muy atento, si quieres te ahorras dinero en guías y libros sobre Barcelona y Cataluña ya que te lo explica todo. Inclusive se ofrece para llevarte a ver sitios que nadie ve. El apartamento a dos pasos de la playa, del Mall y del Metro con el cual podes ir al Centro Histórico, mucho mejor que quedarte en el mismo ya que ni dormirías... Recomendable !!!!'},
#   {'_id': '181155426',
#    'date': datetime.datetime(2017, 8, 12, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '89992896',
#    'reviewer_name': 'Etienne',
#    'comments': 'David est un hôte particulièrement accueillant et arrangeant. Il nous a grandement conseillé mes amis et moi sur la ville de Barcelone. Son appartement est très propre et cocooning. Merci encore à lui pour ce séjour je le recommande.'},
#   {'_id': '185624232',
#    'date': datetime.datetime(2017, 8, 22, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '129454405',
#    'reviewer_name': 'Vivienne',
#    'comments': 'Booking a holiday at this lovely apartment affords the luxury of two vacations rolled into one -- to easily explore the vibrant city of Barcelona, plus relax and unwind at the beach.  That\'s reason enough to chose to stay at Centric Boutique at the Beach.  What comes as a bonus is David, a host who takes pride in what he does and who understands that "goodwill is everything".  It is no surprise that the owner has been awarded the Tripadvisor Certificate of Excellence.  \n\nDavid keeps in touch, checking in to see if/what there is anything we need, in addition to recommending places to visit.  It\'s not just lip service.  For example, we suggested he consider adding a mat in the bathtub, which could be a bit slippery.  Later that day, DONE.\n\nFor example, when it was was time to vacate after our ten-day stay, we asked if would do us the favour of arranging for a mini-van to pick us up at 5:30am, as we were taking a train on to San Sebastian, and couldn\'t risk any misunderstanding if we tried booking this ourselves.  After checking around, David came back with an answer.  The going rate was too high and he was still looking to find us much more reasonable transportation.  He DID.\n\nThis beautifully decorated, two-bedroom apartment is everything as described, well-equipped, well-stocked, clean and comfortable with a lovely balcony and close to all amenities.  \n\nDo we recommend it, most definitely YES.'},
#   {'_id': '188373685',
#    'date': datetime.datetime(2017, 8, 29, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '139956241',
#    'reviewer_name': 'Glenn',
#    'comments': "Our stay at David's apartment was everything it was supposed to be and so much more.  One of the main reasons we chose the apartment was the great reviews that David received as a host.  It turned out that those reviews didn't do him justice.  From the moment I booked, David made sure to stay in contact with us to ensure that we would be fully prepared for our Barcelona experience.  He even offered to pick us up at the airport!  Upon arrival, David gave us a car tour of the city and took us to some out of the way sights that we would have otherwise missed.  The day before we were leaving, I received a message from David offering to drop us back at the  airport.   He went above and beyond to make sure that our time in Barcelona was as wonderful as possible.  David is the ultimate host and I can't recommend him highly enough."},
#   {'_id': '194249033',
#    'date': datetime.datetime(2017, 9, 16, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '16752139',
#    'reviewer_name': 'Abdulrhman',
#    'comments': "Tout d'abord \nL'appartement été très propre dans un endroit calme  a côté de la plage ça traversant un rue pour arriver à la plage ,,\n\nDans l'appartement y'a tous ce qu'il faut pour la cuisine,,\nLe toilette aussi y'a tous ce qu'il faut de Serviettes et savon ،، \nJe me sentais comme si je suis  dans mon appartement.\n \nDavid est un personne  merveilleuse il a bien nos accueillir dans son appartement,, il a nous donné toutes les informations touristiques sur la ville.\nEt il était en contact avec nous Pendant notre séjour pour savoir si on besoin de qqch ou pas ."},
#   {'_id': '207528922',
#    'date': datetime.datetime(2017, 10, 29, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '32671371',
#    'reviewer_name': 'Laura',
#    'comments': 'David is truly a wonderful host. He really took his time to make sure we had all information about the apartment, the area, restaurants, public transport etc. That was wonderful. We felt David was there to help if anything. We had a great weekend!'},
#   {'_id': '210372930',
#    'date': datetime.datetime(2017, 11, 9, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '7529305',
#    'reviewer_name': 'Tony',
#    'comments': 'David is a fantastic host.  Not only did he explain everything about his wonderful apartment, but really covered a lot of detail about the surrounding area - places to eat, drink, avoid!!!  \n\nThe apartment is lovely.  Everything works fantastically well. \n\nIf you are going to the CCIB or beach, this is perfect.\n\nThank you David.  Fantastic host and fantastic apartment.\nTony'},
#   {'_id': '213204189',
#    'date': datetime.datetime(2017, 11, 20, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '52840005',
#    'reviewer_name': 'Dale',
#    'comments': 'Lovely place in between Barcelona and badalona. Great location for shops and a beautiful beach just a few minutes walk. David is a great host and this is his full time job so reply’s within a few minutes and is always on call.  He asked us for 2 and a half hours of our time on arrival to explain the apartment and area which isn’t really needed and can be abit over helpful at times which some people might find annoying but overall 5/5 from me.'},
#   {'_id': '228551006',
#    'date': datetime.datetime(2018, 1, 20, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '41656977',
#    'reviewer_name': 'Tanya',
#    'comments': 'Large apartment within close distance to the city of Barcelona. Good for families or couples as the apartment has two bedrooms with a double bed in one and a queen size in the main. Good sized kitchen with all amenities including a washing machine and dryer. Even supplies such as butter, jam, milk, tea, coffee, wine, olive oil, etc available. Good sized lounge room with views of the courtyard in the middle of the apartment complex. Train station only a 5 minute walk with the underground being a great way to get around. David provided very in depth details and maps of things to do and see in Barcelona and details of the best ways to get around. He was available to answer questions prior to our arrival and during our stay. Check in and out was easy as David was very flexible and able to work in with our flight schedules. '},
#   {'_id': '230511236',
#    'date': datetime.datetime(2018, 1, 28, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '39784223',
#    'reviewer_name': 'Anna',
#    'comments': "Where to begin? Yeah! David, the owner. It's really hard to described how helpful and awesome he is. The best host in all our life. Very kind, friendly. You can always count on him, in every details. He took care of us before we even arrived. He explained how to get to the apartment in the best way. And he was there when we came. Ready to tell us everything. You can ask him about even unexpected things about your stay and be sure he will find an answer in a very short time. How to get to any museum or tourist attraction, where to go in Barcelona,  what to do with kids, where to go to a whole day journey outside the town etc. He's knowledge about Catalonia's history and Catalan architecture is unbelievable. We spending a whole week in Barcelona with our little daughter. She was so happy possessing her own room so she would not go outside. She told us every day she find herself as a princess. She's eight and believe me, she will never said this in our flat. The apartment is amazing. Full of every conveniences you need. Honestly, we haven't got in our own kitchen so many stuff. The apartment is stylish and cosy. So you could feel very comfortable here during your stay. If you need coffee you could make it in many ways, you could cooked here, prepared a dishes, and what it's really really awesome, you could spend a whole evening or night on a lovely terrace. But who wants to stayed on a terrace in Barcelona? If you decided to explore a town, you will find in David's apartment a special guide book which he prepared for his guests. You can't miss it. It's huge as an Encyclopedia Britannica. Neighbours are friendly, you will find a nice bakery and full equipped stores just around the corner. Location is just excellent. Lovely beach is a few blocks from your apartment, underground station just five minutes by walk. Bus stop is on the same corner as a David's apartment. It's hard to believe, but yes. You will find there everything what every high-maintenance resident need. So, if you really want to enjoy your stay at Barcelona, choose this unusual opportunity for living. You will not regret. We are sure! We fell in love with Barcelona, we fell in love with David and we plan to go back as soon as we can. What about next week?"},
#   {'_id': '232242126',
#    'date': datetime.datetime(2018, 2, 4, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '136155801',
#    'reviewer_name': 'Fiona',
#    'comments': 'David is an excellent host, very knowledgable.  His apartment is in a quiet block and looks as good as the photos.  We were attending a conference at the CCIB and it was a 15 min walk along by the sea. It is also about a 10-15 min walk to selva de mare tube station.  Just over an hour from the airport.'},
#   {'_id': '233846062',
#    'date': datetime.datetime(2018, 2, 11, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '15370154',
#    'reviewer_name': 'Neil',
#    'comments': "It is hard to write a review which should be full of superlatives, without making it sound false, but I must try!  \nDavid is truly the perfect host: his love for his city and his dedication to hosting, means he is incredibly generous with his time- the check in is amazing...  The flat is lovely with lots of style, and very well furnished, the location a stone's throw away from easy and quick connections into tow is fantastic.\nI would recommend anyone visiting Barcelona to stay at David's: i simply could not rate him high enough!"},
#   {'_id': '235625837',
#    'date': datetime.datetime(2018, 2, 17, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '61738696',
#    'reviewer_name': 'Shu',
#    'comments': 'David is a very nice guy, everything is perfect.'},
#   {'_id': '242523826',
#    'date': datetime.datetime(2018, 3, 12, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '136357789',
#    'reviewer_name': 'Natasha',
#    'comments': 'David was the perfect host. He was there to meet my friend before I even reached Barcelona, and helped us when we lost a passport. He offered such great insight into all the best things to do and see around Barcelona, advising us on the best routes to get to the popular destinations. The flat was beautiful, with a big kitchen. Walking distance from the metro, we found it very easy to get into the City, without having to pay for a taxi.'},
#   {'_id': '243773678',
#    'date': datetime.datetime(2018, 3, 17, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '102981978',
#    'reviewer_name': 'Jiaxin',
#    'comments': 'David is a very nice person. On our first day in Barcelona, our car has some problems, none of us can speak Spanish so we call David and he came and help us and solve problems. Also, his apartment is very good and tidy. It is good choice for 4 or 5 friend or family to live. Only 5 mins to the beach and shopping mall very convince. We really enjoy the day in Barcelona. Last, David will give you a lot advices for traveling in Barcelona. His apartment is the best choice'},
#   {'_id': '249553633',
#    'date': datetime.datetime(2018, 4, 2, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '18223142',
#    'reviewer_name': 'Fernanda',
#    'comments': 'Espaço incrível, localização maravilhosa e uma super hospitalidade. Barcelona é SENSACIONAL. Espero voltar em breve!'},
#   {'_id': '251153802',
#    'date': datetime.datetime(2018, 4, 7, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '32647741',
#    'reviewer_name': 'Peter',
#    'comments': 'This apartment is great for visiting Barcelona!!'},
#   {'_id': '252612811',
#    'date': datetime.datetime(2018, 4, 11, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '79455354',
#    'reviewer_name': 'Julien',
#    'comments': 'Très bon appartement !!! et super bien localisé.'},
#   {'_id': '255341943',
#    'date': datetime.datetime(2018, 4, 20, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '29686803',
#    'reviewer_name': 'Moayed',
#    'comments': "really I don't know from where I will start\nthe apartment location is perfect near to bus station . underground metro. tourist bus. supermarket .shopping mall . bars .\nthe apartment decoration is amazing appliances. heating .air conditioning . terrace .\nhe made  amazing book that book has a lot of information for the gust \ndavid really friendly man he is so so so nice \nhe come with us to the hospital after that he take us for tour trip for hole day \nreally it was best apartment in the world \nreally I love my stay because of you \nhe didn't leave us any time \nall the time he keep contact me \nwe love our stay and I will come again and again to your apartment\nI recommended this apartment for all \nyou will not fined better this apartment in Barcelona\nhope to see you soon david"},
#   {'_id': '257782412',
#    'date': datetime.datetime(2018, 4, 27, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '39516932',
#    'reviewer_name': 'Femke',
#    'comments': 'We hebben een fantastisch verblijf gehad hier!\nHet appartement is mooi, netjes, schoon, goed uitgerust. We hebben niets gemist, tot aan strandhanddoeken en strandspeelgoed toe. Bedden zijn goed, banken zitten lekker.\nGoede WiFi.\nDavid had zelfs allemaal eten en drinken voor ons klaargezet, zodat we voor de eerste dag/ontbijt al verzorgd waren.\nDavid kan alle info en tips geven over de hele stad etc. Hij reageert op al je vragen direct en staat altijd voor alles klaar.\nDe locatie is ideaal met kinderen, rustig, lekker dicht bij strand en goede aansluiting op alle OV.\nOok voor een congres in het ccib perfect gelegen, minder dan 10 min lopen.\nKortom: perfect voor stedentrip en voor congres!'},
#   {'_id': '265209683',
#    'date': datetime.datetime(2018, 5, 16, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '113101847',
#    'reviewer_name': 'Valeriy',
#    'comments': 'David ist ein super Gasgeber mit vielen hilfreichen Tipps.\nAlles in einem hat man einen schönen Aufenthalt. Die Lage des Appartements ist zentral, liegt jedoch nicht im Herzen der Stadt.'},
#   {'_id': '269400990',
#    'date': datetime.datetime(2018, 5, 27, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '2394737',
#    'reviewer_name': 'Elizabeth',
#    'comments': 'David’s apartment was a wonderful spot for myself and a colleague attending a conference at the convention center. It was a quick ten minute walk there, and yet we had a wonderful place apart from the hustle and bustle. The apartment was extremely well appointed (including coffee, milk, fresh fruit, and muffins!) and within walking distance to a metro stop and the beach. The balcony, looking over the central courtyard was also lovely. It was everything I was hoping for, plus a supremely knowledge, and friendly host!'},
#   {'_id': '273813258',
#    'date': datetime.datetime(2018, 6, 7, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '96948639',
#    'reviewer_name': 'Danny',
#    'comments': "Well what can I say...what a fantastic few days in Barcelona! David was an amazing host, providing us with tonnes of info about Barca; where to visit, how to get about, as well as some local places that are usually hidden to tourists. The apartment itself was awesome. Perfect location, immaculately clean, luxurious, fast wi-fi and the cupboards were stocked with treats! So often apartments are not what they say on the tin, but David's 100% is, and then some. He really does go above and beyond for his guests and is always available if help is ever needed. Can't recommend Davids apartment enough and we can't wait to be back! "},
#   {'_id': '274400039',
#    'date': datetime.datetime(2018, 6, 9, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '12898053',
#    'reviewer_name': 'Ravena',
#    'comments': 'I highly recommend staying at David’s apartment. He puts so much effort into being the best host possible. He treats his guests like family and it makes such a difference in the overall experience. The location is excellent next to the beach, great parks for children, easy transportation, and nice restaurants. Thank you, David!'},
#   {'_id': '275972903',
#    'date': datetime.datetime(2018, 6, 12, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '185670338',
#    'reviewer_name': 'Leigh',
#    'comments': 'You can expect a great host and exactly what you see in the listing.  The location across the street from the beach is perfect. David had a handmade guide book available in the apartment to make exploring Barcelona easy.  Fabulous!'},
#   {'_id': '280447008',
#    'date': datetime.datetime(2018, 6, 23, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '46198021',
#    'reviewer_name': 'Emma',
#    'comments': 'David is the very most professional, helpful and considerate host I ever met, he provides you more than you could ask for. And the apartment is very well organized. Will definitely come back in the future.'},
#   {'_id': '281056530',
#    'date': datetime.datetime(2018, 6, 24, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '127381594',
#    'reviewer_name': 'Marisol',
#    'comments': 'We had a great time in a beautiful city, in a beautiful apartment.  David is a wonderful host and very informative.  The apartment is spacious and immaculate.  David is a gracious host and I only wish we were able to spend a few more days in the apartment and explore the city more.  Thank you David!'},
#   {'_id': '284734527',
#    'date': datetime.datetime(2018, 7, 2, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '2599072',
#    'reviewer_name': 'Kristina',
#    'comments': 'David was hands down the best communicator we have ever worked with during our travels. His response time was great, along with his response to our questions came so much information as to what else do in and around Barcelona. \nFortunately, for us he had an available day to give us a tour of many sights. He took us to places that are not on the usual tourist’s bucket list. \nWe thoroughly enjoyed our tour! We rented a car so having driven around the city, previously with David, made our adventures go much more smoothly!\nDavid’s apartment was clean and very comfortable! I highly recommend booking with him!\nThanks David!'},
#   {'_id': '288678309',
#    'date': datetime.datetime(2018, 7, 10, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '169516029',
#    'reviewer_name': 'Karl',
#    'comments': 'David kümmert sich vorzüglich um seine Gäste.'},
#   {'_id': '290246543',
#    'date': datetime.datetime(2018, 7, 14, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '196993266',
#    'reviewer_name': 'Robert',
#    'comments': 'We would thoroughly recommend David’s apartment - from the friendly welcome and excellent local tips at check-in, the perfect location with the beach very close and the city sights a short trip on the Metro and a stylish and comfortable apartment with thoughtful extra touches. Thank you David!'},
#   {'_id': '299481757',
#    'date': datetime.datetime(2018, 7, 31, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '111043101',
#    'reviewer_name': 'Jackob',
#    'comments': "We are a family of 5 and we can only highly recommend the apartment, its location to site seeing, transportation and the beach. We felt secure and safe in the area and the apartment had everything a family would need, including parking, great Wi-Fi, cable TV, good beds, good space and all the amenities of home. The host was incredibly accommodating, informative and friendly. Here is my note to the owner -  We are back in the States after a very long journey with a cancelled flight!! We truly enjoyed staying with you and your help and hospitality was greatly appreciated. The thoroughness that you went through to ensure we knew the apartment well, the local area and the do's and don'ts in Barcelona, made our trip so much better. and of course thanks so so much for taking us to the airport on the last day, with the taxi strike, that would otherwise have been a big issue for us."},
#   {'_id': '300404736',
#    'date': datetime.datetime(2018, 8, 2, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '125832088',
#    'reviewer_name': 'Kim',
#    'comments': 'David is so hospitable. He had so many nice touches to make life more convenient such as a kitchen stocked with coffee, milk, fabulous muffins, fresh fruit and even his favorite wine.  He is always available for help or advice and tries to do what he can to make your stay extra special! '},
#   {'_id': '302047672',
#    'date': datetime.datetime(2018, 8, 5, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '129937273',
#    'reviewer_name': 'John',
#    'comments': 'Had a wonderful stay at David’s in Barcelona. He was very helpful in organizing the transportation to the unit(which was considerably less expensive than what I’d found online, worked out to 40€ one way and 45€ the other but there are 5 of us so need a bigger taxi) and was waiting when we got there. The hop-on hop-off bus stops nearby which was handy for us and there were many nice restaurants nearby as well as the beach, though wouldn’t recommend the beach. We were coming back from Croatia, they’re much nicer there. To be fair my understanding is most locals go to the beach outside the city where it’s quieter and nicer. Such a beautiful city and this unit is a great place to start if you want to see it!'},
#   {'_id': '306027140',
#    'date': datetime.datetime(2018, 8, 12, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '184208406',
#    'reviewer_name': 'António',
#    'comments': 'Congratulations David,\nOur stay was fantastic, accommodation very good, location is also good.\nThe tips that David gave us were very useful.\nI strongly recommend ...'},
#   {'_id': '309320953',
#    'date': datetime.datetime(2018, 8, 18, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '190102268',
#    'reviewer_name': 'Frédéric',
#    'comments': 'David est un hôte exceptionnel ! Logement au top, guest book mieux que de nombreux guides professionnels, conseils personnalisés, bonnes adresses, disponibilité totale! Si nous revenons à Barcelone, ce sera chez David!'},
#   {'_id': '313318241',
#    'date': datetime.datetime(2018, 8, 25, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '90460632',
#    'reviewer_name': 'Tiffany',
#    'comments': "David nous a accueilli chaleureusement ! Nous à expliqué tous les coins de Barcelone à visiter et à même créer un livre où se trouve toutes les informations nécessaires (visites, restaurants etc) top ! \nL'appartement était propre et très joliment décoré, proche du métro et surtout de la mer ! \nL'appartement est également bien équipé, cafetière, serviettes, ustensiles de cuisine, machine à laver, sèche linge et j'en passe. Il ne manque rien. Les lits sont confortables, pas de bruit pour dormir ce qui est très important pour moi. \nLors de notre arrivée, David nous avait préparé une belle coupe de fruits, mais également acheté de quoi déjeuner et même du vin . \nJe recommande vivement son logement ! David est un super hôte ! "},
#   {'_id': '318761858',
#    'date': datetime.datetime(2018, 9, 4, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '211701467',
#    'reviewer_name': 'Christina',
#    'comments': 'Die Wohnung ist nur zu empfehlen. Sie entspricht eins zu eins dem Profil. Auch die Lage ist perfekt. Direkt am Meer und mit der U Bahn ist man schnell an allen wichtigen Plätzen Barcelonas. Der Gastgeber selbst ist sehr bemüht und gibt einem viele Tipps was man in der Stadt erleben kann. Alles in allem würde ich die Wohnung auf jeden Fall wieder buchen. Es war ein toller Aufenthalt.'},
#   {'_id': '323213720',
#    'date': datetime.datetime(2018, 9, 15, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '55963570',
#    'reviewer_name': 'Sanna',
#    'comments': 'David was by far the best host I have had since using AirBnB. He is super professional, incredibly friendly and reliable. His beautiful appartment is 2 minutes from the beach, with a supernice garden park and a balcony, it offers EVERYTHING you might possibly need...even a garage spot for your car. David provides his guests with fresh fruit, drinks, sweets, coffee and tea and even a little breakfast. The bathroom is fully equipped and there are extra beach towels ready to use. We LOVED it and can only 200 % recommend everyone to book this place.'},
#   {'_id': '324968894',
#    'date': datetime.datetime(2018, 9, 18, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '76333057',
#    'reviewer_name': 'Moses',
#    'comments': 'From booking to checking out David has been fantastic. Answered all our questions and gave us lot of tips for our stay. There are plenty of amenity within 10 mins of walking. The beach is only 5 mins walk. The flat is spacious and David provide everything. All you need to pack is your clothes. He even provide breakfast items like bread, jam and butter. He even fill the fridge with some drinks and milk. The kitchen has a coffee machine as well. Highly recommended.'},
#   {'_id': '326381332',
#    'date': datetime.datetime(2018, 9, 22, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '121674905',
#    'reviewer_name': 'Dzintars',
#    'comments': 'Great host and location'},
#   {'_id': '328775182',
#    'date': datetime.datetime(2018, 9, 27, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '108668003',
#    'reviewer_name': 'Fabienne',
#    'comments': 'The apartment was great and as seen on the pictures! David is a superb host with great hospitality and he gave us some great tips for visiting the city! The apartment was clean and equipped with nice furniture but the location is a bit far away from the city center and from the balcony you can not really see the sea but only the other apartments. All in all it was a great place to stay :) Thx David!'},
#   {'_id': '332413989',
#    'date': datetime.datetime(2018, 10, 5, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '80120931',
#    'reviewer_name': 'Deb',
#    'comments': 'David is a great host!   He has a book full of good tips for visiting Barcelona.   He is willing to help and show you good options for your time in his lovely city.   He clearly wants you to love his city as much as he does.  Highly recommend!'},
#   {'_id': '344261381',
#    'date': datetime.datetime(2018, 11, 3, 4, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '214223295',
#    'reviewer_name': 'Sonja',
#    'comments': 'excellent'},
#   {'_id': '349043875',
#    'date': datetime.datetime(2018, 11, 16, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '216778570',
#    'reviewer_name': 'Mario',
#    'comments': "David made our trip in Barcelona absolutely unforgettable! His apartment is located in a quiet neighborhood, and was the perfect place to unwind after long days of exploring the city. It's super close to both the Metro line and Bus stops, and the beach is a short walk away. David's knowledge of Barcelona's history is incredible; he was able to help us plan out our stay, and make the most out of our experience. The value that he provides simply by being knowledgeable of the city and its best attractions is almost worth the price of staying at his apartment. No matter why you're visiting Barcelona, David will be able to make sure you have the best experience possible. I would HIGHLY recommend his apartment to anyone visiting the city for the first time, or anyone visiting Barcelona again."},
#   {'_id': '353045631',
#    'date': datetime.datetime(2018, 11, 26, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '173917433',
#    'reviewer_name': 'Karen',
#    'comments': "The apartment was a perfect spot for our stay. We loved staying away from the busy part of the city and close to the beach. Even though it's cold in November, we went over to the beach almost every day. The sunrises were stunning!  It was very nice to be in a quiet neighborhood and felt great to be out of the touristy areas. There is a grocery store just a few blocks away and a delicious bakery on the next block. Fresh croissants are the best! \n\nDavid was very helpful and showed the apartment and also offered to tell us all about seeing the city. He communicated through the Airnbn app during the week to make sure all was okay. The best thing was the refrigerator was stocked with water, milk, orange juice, water and even butter and jam. There was coffee and some muffins and toasts for the morning. What a nice touch to see a bowl of fresh fruit on the kitchen table. After a long day of travel, it was very nice to not have to worry about those things needed for the morning. \n\nThe apartment is in a very quiet area with a balcony and windows that look out onto a park. We couldn't hear any cars or traffic at all.\n\nI will definitely recommend the apartment to others. Even though it's a distance from the main part of the city, the Metro is SO easy to use and we could easily get to all of our destinations. We became Metro experts. What a fantastic transit system. If I return to Barcelona, I would definitely stay here again."},
#   {'_id': '353934837',
#    'date': datetime.datetime(2018, 11, 30, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '6902647',
#    'reviewer_name': 'Danielle',
#    'comments': 'David might be the most thorough and thoughtful AirBnB host in the world. His place is perfect and he adds many nice touches like meeting with guests to go over the city and providing fresh fruit, food and wine for visitors. I can’t imagine a better place in Barcelona!'},
#   {'_id': '356155643',
#    'date': datetime.datetime(2018, 12, 7, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '78768495',
#    'reviewer_name': 'Sand',
#    'comments': 'Die Unterkunft ist sehr gut! Sehr gut ausgestattet und in Strandnähe. David ist der beste Gastgeber den wir bis jetzt hatten. Sehr zu empfehlen!'},
#   {'_id': '357406220',
#    'date': datetime.datetime(2018, 12, 10, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '34002605',
#    'reviewer_name': 'Bethany',
#    'comments': 'There needs to be a category above Superhost created for David. He went above and beyond any expectation I had of an Airbnb host, spending so much time welcoming my husband and I to his home, helping us create a custom itinerary for what to see while we were in Spain, and swooping in to help us when a travel plan outside of the city  fell through. Just an absolutely pleasure getting to know him and staying at his place.\n\nThe apartment itself is beautifully decorated and well set up, everything you could need is available. It’s in a quieter neighborhood of the city, which was perfect for us traveling with a small child, but only 3 blocks from the yellow line metro station so we were able to get almost anywhere in the city within 15 minutes. I would highly recommend staying there.'},
#   {'_id': '358170780',
#    'date': datetime.datetime(2018, 12, 13, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '71323391',
#    'reviewer_name': 'John',
#    'comments': 'Cant recommend David and his hospitality highly enough.'},
#   {'_id': '359530298',
#    'date': datetime.datetime(2018, 12, 17, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '13313264',
#    'reviewer_name': 'Diego',
#    'comments': 'Que puedo decir, una maravilla, David es una persona muy dedicada, te sientes a gusto en todo momento, esta en todos los detalles, impecable e inmejorable experiencia. Sin exagerar. Gracias David nuevamente por todo y por tu linda energía. Abrazo. Hasta pronto!'},
#   {'_id': '360900398',
#    'date': datetime.datetime(2018, 12, 22, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '5506474',
#    'reviewer_name': 'Jen',
#    'comments': 'David was a fantastic host and all 3 of us hope to be able to stay with him again. Please take the time to let him tell you about the city, it’s worth it! The apartment is located in a quiet neighborhood with easy access to the metro, perfect for our few days in Barcelona. It’s a well equipped, comfortable, and stylish apartment. It was absolutely the best place we stayed on our road trip through Spain! We loved meeting David and it set the tone for a magical experience in Barcelona.'},
#   {'_id': '364264244',
#    'date': datetime.datetime(2018, 12, 30, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '74916918',
#    'reviewer_name': 'Greg',
#    'comments': "David is a terrific host who feels that he has a responsibility to ensure that you enjoy your stay, not only in his home but in Barcelona as well. Because of this, he goes out of his way to provide his guests with the living space and amenities needed, but also all of the information necessary to have an enjoyable stay. His home is perfectly located in a quiet area easily accessible to the main tourist areas by the city's excellent metro system. The apartment is clean, roomy enough for four (or more), and contains everything necessary for a comfortable stay."},
#   {'_id': '368570651',
#    'date': datetime.datetime(2019, 1, 7, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '29053083',
#    'reviewer_name': 'Osvaldo',
#    'comments': 'pasamos unos días sensacionales, David es un anfitrión de primerísimo nivel, y el apartamento está espectacular, mucho mejor que lo que uno imagina al ver las fotos.\nLa ubicación también es muy buena, a 500 m del metro y a 50 del bus.\nVolveremos seguramente si vamos otra vez a Barcelona.'},
#   {'_id': '369080158',
#    'date': datetime.datetime(2019, 1, 9, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '102910757',
#    'reviewer_name': 'Leon',
#    'comments': "Having stayed various airbnbs over 4 different continents,  I can honestly say that my stay at David's place in Barcelona has been my best experience. The place was clean, cozy and very close to the city center. We were just there for 2 days but David essentially designed an entire travel plan for us. David truly felt like family during our stay and was incredibly helpful in all aspects. Definitely highly recommend for any future trip to Barcelona!"},
#   {'_id': '400512761',
#    'date': datetime.datetime(2019, 1, 12, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '194810863',
#    'reviewer_name': 'Cesar Ernesto',
#    'comments': 'Alojamiento muy cómodo y con muy buen estilo, con Trasporte muy cerca del alojamiento'},
#   {'_id': '402132162',
#    'date': datetime.datetime(2019, 1, 17, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '234924971',
#    'reviewer_name': 'Ana Clara',
#    'comments': 'David offers great and unique assistance , never before have I stayed in an Airbnb with such a good service, location, design and atmosphere all in one! I highly recommend it!'},
#   {'_id': '402694658',
#    'date': datetime.datetime(2019, 1, 19, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '43343008',
#    'reviewer_name': 'Mike',
#    'comments': "Wow! What an incredible experience. We can honestly say this is the best airbnb we have ever stayed in and David is the best airbnb host we have ever had. From the moment we arrived, we were greeted the the most warm welcome from David. He personally met us to walk us through the apartment and answer any questions we might have. He even treated us to coffee across the street and helped us plan our sight-seeing in Barcelona (incredibly helpful!). We were in Barcelona for our honeymoon and we were thrilled that we had such a fantastic experience. The apartment is gorgeous, immaculate and very conveniently located with the beach just down the street and a quick train ride to anywhere you may want to go. We really enjoyed the neighborhood as well! He exceeded every expectation we had and if you're looking to stay in Barcelona, THIS must be your home while you're there. We couldn't recommend it more. Thank you for everything, David! It was absolutely lovely."},
#   {'_id': '404787832',
#    'date': datetime.datetime(2019, 1, 25, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '69884060',
#    'reviewer_name': 'Jyoti',
#    'comments': 'Off all our travels and staying at AirBnBs this has been the BEST experience we have ever had. Amazing Host.  Amazing Location.  Amazing Apartment. LOOK NO FURTHER, YOU WONT REGRET IT!'},
#   {'_id': '407793543',
#    'date': datetime.datetime(2019, 2, 3, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '163510391',
#    'reviewer_name': '지윤',
#    'comments': 'Nice and beautiful place. David was really kind and also told us about tips for Barcelona and hidden places of BCN. It was perfect hosting. Thanks for everything:)'},
#   {'_id': '409019397',
#    'date': datetime.datetime(2019, 2, 6, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '131504877',
#    'reviewer_name': 'Christin',
#    'comments': 'David was an awesome host! Very thoughtful, very detailed, very organized and I would stay at his place again in a heartbeat!'},
#   {'_id': '411103448',
#    'date': datetime.datetime(2019, 2, 11, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '156762255',
#    'reviewer_name': 'Jingjie',
#    'comments': 'David是特别好的房东,细致贴心,非常周到,还准备了许多吃的｡房间宽敞,干净,很舒适,地下停车库也很方便｡'},
#   {'_id': '414349367',
#    'date': datetime.datetime(2019, 2, 19, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '43857932',
#    'reviewer_name': 'Bob',
#    'comments': 'I want to start with talking about the Host, David. David contacted us professionally before our stay so we knew he would be good, but he certainly hit it out of the park with his incredible information about the area, perfectly clean apartment, all the thoughtful extras and the taking care of any question or problem we had (none with the apartment, but we almost missed our flight and he was a great help). David is the most thoughtful, gracious host.\nHe provided us with all the information we needed and showed us around. The apartment is just perfect! Kitchen is roomy, and it contains everything one needs.\nThe beds are comfortable, bathroom and terrace overlooking a nice courtyard with olive trees, are excellent. Location is incredible right near all the transportation lines (we never needed to cab it other than our manic ride to the airport when I mixed up our departure time by several hours, metro and bus is right there to all of Barcelona).\nDavid had excellent restaurant, sightseeing and transportation recommendations and was of great help.  He shares everything he knows abour Barcelona, and it is comprehensive. He went way beyond anything I would call usual (though it seems to be for him) to make our long-weekend comfortable and memorable. I consider him a friend now!\nQuiet neighborhood. Seems to be a lot of families here and it is very safe. You can walk here at any time, day or night. There is a cooking school right across the street and it was a great deal. 2 blocks over we attended an arts festival, the beach is 2 blocks the other way. On Sunday, we actually walked from La Rambla, to the seaport, down the beach and then to the apartment, seeing sights, people, entertainers and every type of food, beer and wine. What a great place.\nWe could go on and on, but to summarize, this is a great, roomy apartment, fullequipped, central to all transportation, right near the beach, restaurants and things to do right nearby, David is fantastic (best host ever!). We hope to go back soon.'},
#   {'_id': '416202436',
#    'date': datetime.datetime(2019, 2, 24, 5, 0),
#    'listing_id': '13382536',
#    'reviewer_id': '108103876',
#    'reviewer_name': 'Paul',
#    'comments': 'A fabulous apartment in a great location, quiet, but convenient for public transport, shops restaurants etc. David was a very thorough host, giving lots of excellent tips & advice. We would definitely like to return here.'}]}

# %%
show_all(
    coll.find(
        {'address.country_code': 'BR', 'bedrooms': 2},
        {'address.country_code': 1, 'bedrooms': 1}
    )
)
# Out:
# [{'_id': '10411341', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '10570041', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '10201975', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '10706900', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '12091894', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '12234922', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '17693637', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '1940174', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '20116519', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '20055406', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '15177216', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '20599393', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '21291633', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '22952561', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '17124591', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '2851471', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '30032152', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '3040870', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '4790136', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '484267', 'address': {'country_code': 'BR'}, 'bedrooms': 2},
#  {'_id': '654519', 'address': {'country_code': 'BR'}, 'bedrooms': 2}]

# %%
show_all(
    coll.find(
        {'address.country_code': 'BR'},
        {'name': 1, 'host.host_name': 1}
    )
)
# Out:
# [{'_id': '10635276',
#   'host': {'host_name': 'Luiz Henrique'},
#   'name': 'GREAT Apartment at Barra da Tijuca'},
#  {'_id': '10038496',
#   'host': {'host_name': 'Ana Valéria'},
#   'name': 'Copacabana Apartment Posto 6'},
#  {'_id': '13810527',
#   'host': {'host_name': 'Paulo'},
#   'name': 'HUMAITÁ - VIEW OF THE CRISTO REDENTOR STATUE'},
#  {'_id': '10373872',
#   'host': {'host_name': 'Marcelo'},
#   'name': 'Apartamento Mobiliado - Lgo do Machado'},
#  {'_id': '10411341',
#   'host': {'host_name': 'Liliane'},
#   'name': 'Beautiful flat with services'},
#  {'_id': '10570041',
#   'host': {'host_name': 'Roberta (Beta) Gatti'},
#   'name': 'Jardim Botânico Gourmet 2 bdroom'},
#  {'_id': '10201975',
#   'host': {'host_name': 'Barbara'},
#   'name': 'Ipanema: moderno apê 2BR + garagem'},
#  {'_id': '15015363',
#   'host': {'host_name': 'Vera'},
#   'name': 'Achei! Loft  na praia, moderno e equipado.'},
#  {'_id': '10706900',
#   'host': {'host_name': 'Aline'},
#   'name': 'Apart-hotel w/ Wonderful Ocean View - 2 bedrooms!!'},
#  {'_id': '11740322',
#   'host': {'host_name': 'Rafaela'},
#   'name': '★Cozy doble bedroom ★Nearby Christ the Redeemer★'},
#  {'_id': '10267144',
#   'host': {'host_name': 'Cesar'},
#   'name': 'IPANEMA LUXURY PENTHOUSE with MAID'},
#  {'_id': '12091894',
#   'host': {'host_name': 'Armando'},
#   'name': 'Apartment in Ipanema with Balcony'},
#  {'_id': '13324467', 'host': {'host_name': 'Raygs'}, 'name': 'Loft Copacabana'},
#  {'_id': '13390320',
#   'host': {'host_name': 'Leo&Archanjo'},
#   'name': 'Alegre&Aconchegante p/até 4 Posto10'},
#  {'_id': '11939367',
#   'host': {'host_name': 'Assunção De Fatima'},
#   'name': 'Suíte TOP frente Mar Barra posto 4 + Café da Manhã'},
#  {'_id': '13937802',
#   'host': {'host_name': 'Conceição'},
#   'name': 'Bed & Breakfast - Near the Maracanã'},
#  {'_id': '11695437',
#   'host': {'host_name': 'Dejanira'},
#   'name': 'Cozy and modern Lapa-studio'},
#  {'_id': '13411324',
#   'host': {'host_name': 'Teresa'},
#   'name': 'Um Quarto Aconchegante em Ipanema'},
#  {'_id': '12234922',
#   'host': {'host_name': 'Ida'},
#   'name': 'Room in apartment with beautiful view, in Botafogo'},
#  {'_id': '12639342',
#   'host': {'host_name': 'Sonia'},
#   'name': '1BR COZY, SPACIOUS, NEXT TO METRO FLAMENGO, RIO'},
#  {'_id': '12651199',
#   'host': {'host_name': 'Leander'},
#   'name': 'Private apartment, small and comfortable.'},
#  {'_id': '17494671',
#   'host': {'host_name': 'Isabel'},
#   'name': 'ótimo quarto em ambiente tranquilo e aconchegante'},
#  {'_id': '17693637',
#   'host': {'host_name': 'Paulo Cesar'},
#   'name': 'Apartamento no Flamengo para temporadas'},
#  {'_id': '1940174',
#   'host': {'host_name': 'Rafael'},
#   'name': 'COPACABANA luxurious apartment 2BR'},
#  {'_id': '13304991',
#   'host': {'host_name': 'Sergio'},
#   'name': 'The charming blue suite - Copacabana'},
#  {'_id': '182139',
#   'host': {'host_name': 'Ylza'},
#   'name': 'Cozy Bedroom in Copacabana! R3'},
#  {'_id': '20116519',
#   'host': {'host_name': 'Cassio'},
#   'name': 'Linda Vista na Reserva, Barra da Tijuca'},
#  {'_id': '20055406',
#   'host': {'host_name': 'Daniel'},
#   'name': '2 Marvellous ENSUITES with lazer area IPANEMA'},
#  {'_id': '14996051',
#   'host': {'host_name': 'Vitor & Carlos'},
#   'name': 'Best location near the beach at Posto 9'},
#  {'_id': '15177216',
#   'host': {'host_name': 'Carolina'},
#   'name': 'COPACABANA BEACH- REVEILLON -WI FI FREE -Cable TV'},
#  {'_id': '20969380',
#   'host': {'host_name': 'Aline'},
#   'name': '2 Apês no mesmo apart-hotel (3 quartos e 1 quarto)'},
#  {'_id': '22058660',
#   'host': {'host_name': 'Assunção De Fatima'},
#   'name': 'Apartamento Design VIP Praia da Barra - 3 quartos'},
#  {'_id': '20599393',
#   'host': {'host_name': 'Maria Lucia'},
#   'name': 'Apartamento entre a Praia de Copacabana e o Metrô'},
#  {'_id': '2263327',
#   'host': {'host_name': 'Igor'},
#   'name': 'Private Room in Copacabana  -> The Best Price! :)'},
#  {'_id': '2116352',
#   'host': {'host_name': 'Ewa'},
#   'name': 'Private room with great breakfast'},
#  {'_id': '21291633',
#   'host': {'host_name': 'Rio World Luxury'},
#   'name': 'GREAT 2BDR PENTHOUSE 100m TO COPACABANA BEACH'},
#  {'_id': '16036940',
#   'host': {'host_name': 'Eneide'},
#   'name': 'Aconchego entre a Praia e a Lagoa'},
#  {'_id': '2213067',
#   'host': {'host_name': 'Claudia'},
#   'name': 'RIO BY THE BEACH CONDO BARRA DA TIJUCA'},
#  {'_id': '22952561',
#   'host': {'host_name': 'Luiz Felipe'},
#   'name': 'Apartamento Carnacopa. Copacabana Flat!'},
#  {'_id': '17124591',
#   'host': {'host_name': 'Rafa'},
#   'name': 'Lindo apartamento em Copacabana bem localizado'},
#  {'_id': '23606639',
#   'host': {'host_name': 'Alexander'},
#   'name': 'Beautiful Suite at Rio Stay Residénce'},
#  {'_id': '24917622',
#   'host': {'host_name': 'Vera'},
#   'name': 'Copacabana-Apto Conjugado-4 pessoas- Posto 2,5'},
#  {'_id': '1797689',
#   'host': {'host_name': 'Sergio'},
#   'name': 'STUDIO IN COPACABANA'},
#  {'_id': '26463049',
#   'host': {'host_name': 'Tereza'},
#   'name': 'Apto Quarto e Sala Copacabana Posto 4'},
#  {'_id': '2422745',
#   'host': {'host_name': 'Mônica'},
#   'name': 'So close of tourist attractions :)'},
#  {'_id': '2681380',
#   'host': {'host_name': 'Paula'},
#   'name': 'Copacabana Beach - One block'},
#  {'_id': '26816279',
#   'host': {'host_name': 'Vitor & Carlos'},
#   'name': 'Copacabana, near the beach and cheap'},
#  {'_id': '24717812',
#   'host': {'host_name': 'Thaisa'},
#   'name': 'Conjugado Leblon 10min da praia e 5min metrô a pé.'},
#  {'_id': '2851471',
#   'host': {'host_name': 'Deborah'},
#   'name': 'Perfect and charming apt in Leblon'},
#  {'_id': '2875373',
#   'host': {'host_name': 'Marcos'},
#   'name': 'Nice Room for Two in Copacabana'},
#  {'_id': '20845825',
#   'host': {'host_name': 'Diogo'},
#   'name': 'Charmoso Studio em Ipanema'},
#  {'_id': '30032152',
#   'host': {'host_name': 'Andrea'},
#   'name': 'Otimo apartamento no Leblon'},
#  {'_id': '2187573',
#   'host': {'host_name': 'Rafael'},
#   'name': 'Lovely studio Copacabana next to beach and subway'},
#  {'_id': '22232299',
#   'host': {'host_name': 'Heidy'},
#   'name': 'Quarto de casal próximo ao aeroporto Galeão'},
#  {'_id': '22420791',
#   'host': {'host_name': 'Anna Gabrielle'},
#   'name': 'Apartamento no Recreio dos Bandeirantes'},
#  {'_id': '3040870',
#   'host': {'host_name': 'John'},
#   'name': 'Copacabana Bela Vista Apartment  2 - Ocean View!'},
#  {'_id': '22950622',
#   'host': {'host_name': 'Rúben'},
#   'name': 'Copacabana, Rio de Janeiro, Ottima posizione'},
#  {'_id': '30716077',
#   'host': {'host_name': 'Margarida & Cesar'},
#   'name': 'Seguro & Simples & Barato'},
#  {'_id': '23644123',
#   'host': {'host_name': 'Daniel'},
#   'name': 'Party/Event – Day/Night – Botafogo/Laranjeiras!'},
#  {'_id': '2515976',
#   'host': {'host_name': 'Frederico & Marcela'},
#   'name': '2- AMAZING FLAT IN RIO DE JANEIRO 201/301'},
#  {'_id': '2683147',
#   'host': {'host_name': 'Rodrigo Guandelini'},
#   'name': 'Premium Ipanema & Copacabana.'},
#  {'_id': '3800450',
#   'host': {'host_name': 'Carolina'},
#   'name': 'Ipanema Beach Apartment!! Ocean and Island View!!'},
#  {'_id': '30950498',
#   'host': {'host_name': 'RioHost'},
#   'name': 'Cobertura Duplex Barra'},
#  {'_id': '4467174',
#   'host': {'host_name': 'Kai'},
#   'name': 'MEERBLICK TROPICAL SUITE   CK'},
#  {'_id': '8043869',
#   'host': {'host_name': 'Aracele'},
#   'name': 'Best location of ipanema- Rent Room'},
#  {'_id': '31984148',
#   'host': {'host_name': 'Claudio'},
#   'name': 'Copacabana Apartment Near Beach and Subway'},
#  {'_id': '3210248',
#   'host': {'host_name': 'Bruno'},
#   'name': 'The best point at Barra da Tijuca!'},
#  {'_id': '4790136',
#   'host': {'host_name': 'Beth'},
#   'name': 'Paradise in Leblon'},
#  {'_id': '9172046',
#   'host': {'host_name': 'Marcelo'},
#   'name': 'Family ap. in best place of Ipanema'},
#  {'_id': '484267',
#   'host': {'host_name': 'Celia'},
#   'name': 'Cozy Penthouse between Copacabana and Ipanema'},
#  {'_id': '4987188',
#   'host': {'host_name': 'Vilma E Sidney'},
#   'name': 'Copacabana Christ the Redeemer view'},
#  {'_id': '332150',
#   'host': {'host_name': 'Casa 48 Guesthouse'},
#   'name': 'GREAT VIEW -Santa Teresa- GUESTHOUSE "Casa 48"  #2'},
#  {'_id': '926669',
#   'host': {'host_name': 'Renata'},
#   'name': 'Heart of Copacabana: 1 Minute to Beach'},
#  {'_id': '9369576',
#   'host': {'host_name': 'Alexandre'},
#   'name': 'Great Penthouse with a view in a friendly Favela'},
#  {'_id': '3448897',
#   'host': {'host_name': 'Jamil Alberto'},
#   'name': 'Studio em Copacabana a 50 metros da praia'},
#  {'_id': '9643051',
#   'host': {'host_name': 'Ewa'},
#   'name': 'Private room with great breakfast 3'},
#  {'_id': '5814254',
#   'host': {'host_name': 'Rachel'},
#   'name': 'Aparthotel at Praia da Barra.'},
#  {'_id': '9987200',
#   'host': {'host_name': 'Dumont'},
#   'name': 'The best suite in Copacabana (total privacy)'},
#  {'_id': '654519',
#   'host': {'host_name': 'Marcos'},
#   'name': 'Ipanema Great 2-bedroom Cozy Apt'},
#  {'_id': '664017',
#   'host': {'host_name': 'Mari'},
#   'name': 'Copacabana Private Family Room : )'},
#  {'_id': '490098',
#   'host': {'host_name': 'Renata'},
#   'name': 'Best location in Leblon - 1 bedroom'},
#  {'_id': '4915245',
#   'host': {'host_name': 'Carlos'},
#   'name': 'Cozy mini-studio, one block from the beach.'},
#  {'_id': '4924343',
#   'host': {'host_name': 'Ricardo'},
#   'name': 'Confortável quarto com varanda  em Copacabana.'},
#  {'_id': '4964534',
#   'host': {'host_name': 'Pablo And Gloria'},
#   'name': 'Bucolic Eco Art House Cézanne Suite'},
#  {'_id': '6778993',
#   'host': {'host_name': 'Marilene'},
#   'name': 'Lindo Loft praia Copacabana/ Leme!'},
#  {'_id': '746187',
#   'host': {'host_name': 'Silvia E Sidiney'},
#   'name': 'Homy Cozy Place'},
#  {'_id': '846689',
#   'host': {'host_name': 'Monica'},
#   'name': 'Copacabana Beautiful Studio Beside Ipanema'},
#  {'_id': '880678',
#   'host': {'host_name': 'Paulo'},
#   'name': 'Comfort and Safety in Ipanema!'}]

# %%
show_all(coll.aggregate( [
  {
    '$group': {'_id': '$bedrooms', 'how_many': {'$sum': 1}, 'avg_bath': {'$avg': '$bathrooms'}}
  }
]))
# Out:
# [{'_id': 0,
#   'avg_bath': Decimal128('1.012195121951219512195121951219512'),
#   'how_many': 123},
#  {'_id': 3,
#   'avg_bath': Decimal128('2.020833333333333333333333333333333'),
#   'how_many': 72},
#  {'_id': 5, 'avg_bath': Decimal128('3.0'), 'how_many': 1},
#  {'_id': 6, 'avg_bath': Decimal128('5.0'), 'how_many': 1},
#  {'_id': 8, 'avg_bath': Decimal128('5.0'), 'how_many': 2},
#  {'_id': 7, 'avg_bath': Decimal128('3.0'), 'how_many': 3},
#  {'_id': 1,
#   'avg_bath': Decimal128('1.087227414330218068535825545171340'),
#   'how_many': 643},
#  {'_id': 2,
#   'avg_bath': Decimal128('1.479166666666666666666666666666667'),
#   'how_many': 216},
#  {'_id': 4,
#   'avg_bath': Decimal128('2.793103448275862068965517241379310'),
#   'how_many': 29}]

# %%
show_all(coll.aggregate([
    {
      '$group': {
        '_id': '$address.country_code',
        'bed': {'$avg': '$bedrooms'},
        'bath': {'$avg': '$bathrooms'},
      }
    },
    {
        '$project': {
            '_id': 0,
            'country': '$_id',
            'rooms': {'$add': ['$bed','$bath'] }
        }
    }
]))
# Out:
# [{'country': 'BR', 'rooms': Decimal128('2.744318181818181878739437706826720')},
#  {'country': 'HK', 'rooms': Decimal128('2.277777777777777769553903521295137')},
#  {'country': 'AU', 'rooms': Decimal128('2.608208955223880524104756591780765')},
#  {'country': 'ES', 'rooms': Decimal128('2.608695652173912956591241551074706')},
#  {'country': 'CA', 'rooms': Decimal128('2.579439252336448537950527637141047')},
#  {'country': 'PT', 'rooms': Decimal128('2.649397590361445686824026779504493')},
#  {'country': 'US', 'rooms': Decimal128('2.628787878787878812550410648235802')},
#  {'country': 'TR', 'rooms': Decimal128('2.72')},
#  {'country': 'CN', 'rooms': Decimal128('1.666666666666666629659232512494782')}]

# %%
coll.update
# Out:
# <bound method Collection.update of Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_airbnb'), 'listingsAndReviews')>

# %%
[x for x in coll.find({'name': {'$regex': 'Cottage'}}, {'name':True})]
# Out:
# [{'_id': '4532565', 'name': '"Grandpa\'s Cottage" 2 Story Studio'},
#  {'_id': '20680853', 'name': 'Beachhouse Kailua: Cottage with Green A/C'},
#  {'_id': '4774436', 'name': 'Charming Beach Cottage in Ewa Beach'},
#  {'_id': '23222456', 'name': 'Cosy Cottage blue'},
#  {'_id': '11379251', 'name': 'Cottage on Kona Coffee Farm'},
#  {'_id': '28387985', 'name': 'English Cottage in Hawaii'},
#  {'_id': '9701620',
#   'name': 'Glebe Treetop Cottage. Just 200m to Sydney Harbour'},
#  {'_id': '8764966', 'name': 'Heart of Hana, 1BR/1BA Cottage'},
#  {'_id': '15787147',
#   'name': 'Hunter Hales is the Perfect Getaway!  KALA Cottage'},
#  {'_id': '14996590', 'name': 'Kailua Cottage'},
#  {'_id': '9152841', 'name': 'Kona Country Cottage (Clean and Cozy)'},
#  {'_id': '20557566',
#   'name': 'Kuuipo Cottage Romantic Volcano Rainforest Retreat'},
#  {'_id': '1714235', 'name': 'Sandstone Cottage, Great Mackerel Beach'},
#  {'_id': '16242685',
#   'name': 'Seaside Cottage - A sand beach is your front yard!'},
#  {'_id': '4580916', 'name': 'Tara Cottage:a Haven for Relaxation'},
#  {'_id': '18616850',
#   'name': 'The Paddington Cottage | Sydney Eastern Suburbs'}]

# %% [markdown]
# ```py
# coll.find({ 'accommodates': { '$gt': 5 } });
# ```
#
# Full list: https://www.mongodb.com/docs/v4.4/reference/operator/query/
#
# **Exercise**: Find all of the listings with a rating above least 90.
#
# **Exercise**: Find all of the listings with more than two bedrooms and a weekly price of less than $1000.
#
# **Exercise**: Find all of the condos and apartments in the US whose host is named "Alex".
#
# *Note:* If you're not sure what properties exist on a document, you can call `.keys()`.

# %%
coll = db.listingsAndReviews

# %%
coll.find().next().keys()

# %%
counts = dict()
for item in coll.find():
    for key in item.keys():
        if key in counts:
            counts[key] += 1
        else:
            counts[key] =  1

print(counts)

# %%
apartment['review_scores']['review_scores_rating']

# %% [markdown]
# ```py
# # Get listings that accommodate more than five guests
# coll.find({ 'accommodates': { '$gt': 5 } });
# ```
#
# Full list: https://www.mongodb.com/docs/v4.4/reference/operator/query/
#
# **Exercise**: Find all of the listings with a rating above least 90.
#
# **Exercise**: Find all of the listings with more than two bedrooms and a weekly price of less than $1000.
#
# **Exercise**: Find all of the condos and apartments in the US whose host is named "Alex".
#
# *Note:* If you're not sure what properties exist on a document, you can call `.keys()`.

# %%
coll.find({'review_scores.review_scores_rating': {'$gte': 90}}).next()['review_scores']

# %%
cheap = coll.find({'bedrooms': {'$gt':2}, 'weekly_price': {'$lt': 1000}}).next()

# %%
cheap['weekly_price']

# %%
coll.find({ 'amenities': { '$all': ["Internet", "TV"] } }).next()

# %%
db = client.lec9
db.create_collection('students')

# %%
# db.collection.insert( <object> )
db.students.insert_one({"name": "Alex"});
db.students.insert_one({"student_id": "N10234567"});
# Use an array to insert several objects
db.students.insert_many([{"name": "Charlie"}, {"name": "Dylan"}])

# %%
db.students.delete_many({}) # Delete everything

# %%
cottages = coll.find({'name': {'$regex': 'Cottage'}})
# SELECT name FROM coll WHERE name LIKE '%Cottage%';

print([c['name'] for c in cottages])

# If we want to re-enumerate our query, we have to rewind the cursor
cottages.rewind()

# Dump to file
with open('cottages.json','w') as f:
    f.write(dumps(cottages,indent=2))

# %%
with open('cottages.json','r') as f:
    cottages_2 = loads(f.read())

# %%
filter = {'address.country_code': {'$in': ['BR','CA']}}
proj = {'host.host_name':1}
[x for x in coll.find(filter,proj)]
# Out:
# [{'_id': '10635276', 'host': {'host_name': 'Luiz Henrique'}},
#  {'_id': '10038496', 'host': {'host_name': 'Ana Valéria'}},
#  {'_id': '13810527', 'host': {'host_name': 'Paulo'}},
#  {'_id': '10373872', 'host': {'host_name': 'Marcelo'}},
#  {'_id': '10411341', 'host': {'host_name': 'Liliane'}},
#  {'_id': '14629833', 'host': {'host_name': 'Laurence'}},
#  {'_id': '10570041', 'host': {'host_name': 'Roberta (Beta) Gatti'}},
#  {'_id': '1019168', 'host': {'host_name': 'Lilou'}},
#  {'_id': '10201975', 'host': {'host_name': 'Barbara'}},
#  {'_id': '15015363', 'host': {'host_name': 'Vera'}},
#  {'_id': '10706900', 'host': {'host_name': 'Aline'}},
#  {'_id': '11740322', 'host': {'host_name': 'Rafaela'}},
#  {'_id': '10267144', 'host': {'host_name': 'Cesar'}},
#  {'_id': '16002924', 'host': {'host_name': 'Nicky'}},
#  {'_id': '12091894', 'host': {'host_name': 'Armando'}},
#  {'_id': '13324467', 'host': {'host_name': 'Raygs'}},
#  {'_id': '13390320', 'host': {'host_name': 'Leo&Archanjo'}},
#  {'_id': '16078823', 'host': {'host_name': 'Filomena'}},
#  {'_id': '11939367', 'host': {'host_name': 'Assunção De Fatima'}},
#  {'_id': '13937802', 'host': {'host_name': 'Conceição'}},
#  {'_id': '11695437', 'host': {'host_name': 'Dejanira'}},
#  {'_id': '13411324', 'host': {'host_name': 'Teresa'}},
#  {'_id': '13508417', 'host': {'host_name': 'Sofia'}},
#  {'_id': '12234922', 'host': {'host_name': 'Ida'}},
#  {'_id': '14896503', 'host': {'host_name': 'William'}},
#  {'_id': '18272882', 'host': {'host_name': 'Sarah'}},
#  {'_id': '12639342', 'host': {'host_name': 'Sonia'}},
#  {'_id': '12651199', 'host': {'host_name': 'Leander'}},
#  {'_id': '1589452', 'host': {'host_name': 'Barbara'}},
#  {'_id': '18485581', 'host': {'host_name': 'Tanguy & Uriel'}},
#  {'_id': '18734995', 'host': {'host_name': 'Marie'}},
#  {'_id': '18776184', 'host': {'host_name': 'Alfredo'}},
#  {'_id': '16401542', 'host': {'host_name': 'Adelyna'}},
#  {'_id': '16517991', 'host': {'host_name': 'Richard'}},
#  {'_id': '12973335', 'host': {'host_name': 'Alexia & Denis'}},
#  {'_id': '16976284', 'host': {'host_name': 'Steven'}},
#  {'_id': '19030572', 'host': {'host_name': 'Shereen'}},
#  {'_id': '19080306', 'host': {'host_name': 'Sakina'}},
#  {'_id': '17494671', 'host': {'host_name': 'Isabel'}},
#  {'_id': '16389574', 'host': {'host_name': 'Matt, Aaron And Kaileigh'}},
#  {'_id': '17693637', 'host': {'host_name': 'Paulo Cesar'}},
#  {'_id': '1940174', 'host': {'host_name': 'Rafael'}},
#  {'_id': '19555586', 'host': {'host_name': 'Sarah & Aristide'}},
#  {'_id': '13304991', 'host': {'host_name': 'Sergio'}},
#  {'_id': '182139', 'host': {'host_name': 'Ylza'}},
#  {'_id': '20116519', 'host': {'host_name': 'Cassio'}},
#  {'_id': '19825124', 'host': {'host_name': 'Sarah'}},
#  {'_id': '17861859', 'host': {'host_name': 'Fanny'}},
#  {'_id': '17892346', 'host': {'host_name': 'Dominic'}},
#  {'_id': '20605168', 'host': {'host_name': 'Andréanne'}},
#  {'_id': '20055406', 'host': {'host_name': 'Daniel'}},
#  {'_id': '18119842', 'host': {'host_name': 'Laurel'}},
#  {'_id': '19340381', 'host': {'host_name': 'Marina'}},
#  {'_id': '20394583', 'host': {'host_name': 'Tony'}},
#  {'_id': '20455499', 'host': {'host_name': 'Simon'}},
#  {'_id': '19961067', 'host': {'host_name': 'Hernan'}},
#  {'_id': '14996051', 'host': {'host_name': 'Vitor & Carlos'}},
#  {'_id': '15177216', 'host': {'host_name': 'Carolina'}},
#  {'_id': '20969380', 'host': {'host_name': 'Aline'}},
#  {'_id': '22058660', 'host': {'host_name': 'Assunção De Fatima'}},
#  {'_id': '20599393', 'host': {'host_name': 'Maria Lucia'}},
#  {'_id': '2071929', 'host': {'host_name': 'Carole'}},
#  {'_id': '15581379', 'host': {'host_name': 'Unal'}},
#  {'_id': '2263327', 'host': {'host_name': 'Igor'}},
#  {'_id': '22707139', 'host': {'host_name': 'Cedric'}},
#  {'_id': '2116352', 'host': {'host_name': 'Ewa'}},
#  {'_id': '21291633', 'host': {'host_name': 'Rio World Luxury'}},
#  {'_id': '16036940', 'host': {'host_name': 'Eneide'}},
#  {'_id': '21853819', 'host': {'host_name': 'Jesus'}},
#  {'_id': '2213067', 'host': {'host_name': 'Claudia'}},
#  {'_id': '23527078', 'host': {'host_name': 'Julie'}},
#  {'_id': '22717303', 'host': {'host_name': 'Jade'}},
#  {'_id': '22464989', 'host': {'host_name': 'Catherine'}},
#  {'_id': '22613522', 'host': {'host_name': 'Mathilde'}},
#  {'_id': '16869922', 'host': {'host_name': 'Agnès'}},
#  {'_id': '23688192', 'host': {'host_name': 'Alexia'}},
#  {'_id': '22952561', 'host': {'host_name': 'Luiz Felipe'}},
#  {'_id': '17124591', 'host': {'host_name': 'Rafa'}},
#  {'_id': '23606639', 'host': {'host_name': 'Alexander'}},
#  {'_id': '24917622', 'host': {'host_name': 'Vera'}},
#  {'_id': '23771506', 'host': {'host_name': 'Greatest'}},
#  {'_id': '2400861', 'host': {'host_name': 'Jason'}},
#  {'_id': '23769045', 'host': {'host_name': 'Christopher'}},
#  {'_id': '23822150', 'host': {'host_name': 'Yanick'}},
#  {'_id': '23921295', 'host': {'host_name': 'Jonathan'}},
#  {'_id': '17575897', 'host': {'host_name': 'Ioni'}},
#  {'_id': '24279661', 'host': {'host_name': 'Pine Tree'}},
#  {'_id': '1797689', 'host': {'host_name': 'Sergio'}},
#  {'_id': '25070084', 'host': {'host_name': 'Nikki'}},
#  {'_id': '26231187', 'host': {'host_name': 'Luna'}},
#  {'_id': '25266022', 'host': {'host_name': 'Berish'}},
#  {'_id': '26463049', 'host': {'host_name': 'Tereza'}},
#  {'_id': '26779943', 'host': {'host_name': 'Philippe'}},
#  {'_id': '19337464', 'host': {'host_name': 'Tristan'}},
#  {'_id': '27720921', 'host': {'host_name': 'Yaw And Anyele'}},
#  {'_id': '24159286', 'host': {'host_name': 'Irina'}},
#  {'_id': '2422745', 'host': {'host_name': 'Mônica'}},
#  {'_id': '24462062', 'host': {'host_name': 'Unal'}},
#  {'_id': '2681380', 'host': {'host_name': 'Paula'}},
#  {'_id': '26816279', 'host': {'host_name': 'Vitor & Carlos'}},
#  {'_id': '26832903', 'host': {'host_name': 'Good Living'}},
#  {'_id': '24717812', 'host': {'host_name': 'Thaisa'}},
#  {'_id': '25014628', 'host': {'host_name': 'Rachel & Hamza'}},
#  {'_id': '28135558', 'host': {'host_name': 'Irina'}},
#  {'_id': '28384382', 'host': {'host_name': 'Noémie'}},
#  {'_id': '25261646', 'host': {'host_name': 'Abdou'}},
#  {'_id': '2851471', 'host': {'host_name': 'Deborah'}},
#  {'_id': '26365414', 'host': {'host_name': 'Jean-Pierre'}},
#  {'_id': '26565457', 'host': {'host_name': 'Lucie'}},
#  {'_id': '26740256', 'host': {'host_name': 'Christopher'}},
#  {'_id': '2054110', 'host': {'host_name': 'Martin'}},
#  {'_id': '20588113', 'host': {'host_name': 'Jose'}},
#  {'_id': '28660186', 'host': {'host_name': 'Marie-José'}},
#  {'_id': '28714475', 'host': {'host_name': 'Nohora'}},
#  {'_id': '2875373', 'host': {'host_name': 'Marcos'}},
#  {'_id': '29165158', 'host': {'host_name': 'Amal'}},
#  {'_id': '29222035', 'host': {'host_name': 'Amal'}},
#  {'_id': '20728606', 'host': {'host_name': 'John'}},
#  {'_id': '20845825', 'host': {'host_name': 'Diogo'}},
#  {'_id': '27259809', 'host': {'host_name': 'Gilles'}},
#  {'_id': '28782308', 'host': {'host_name': 'Olivier'}},
#  {'_id': '28838517', 'host': {'host_name': 'Isabelle'}},
#  {'_id': '28881873', 'host': {'host_name': 'Anh'}},
#  {'_id': '21145923', 'host': {'host_name': 'René'}},
#  {'_id': '29947519', 'host': {'host_name': 'Gabriel'}},
#  {'_id': '30032152', 'host': {'host_name': 'Andrea'}},
#  {'_id': '21865684', 'host': {'host_name': 'Le Bed & Cocktail'}},
#  {'_id': '2187573', 'host': {'host_name': 'Rafael'}},
#  {'_id': '22232299', 'host': {'host_name': 'Heidy'}},
#  {'_id': '22420791', 'host': {'host_name': 'Anna Gabrielle'}},
#  {'_id': '3040870', 'host': {'host_name': 'John'}},
#  {'_id': '22950622', 'host': {'host_name': 'Rúben'}},
#  {'_id': '30716077', 'host': {'host_name': 'Margarida & Cesar'}},
#  {'_id': '23494020', 'host': {'host_name': 'Noemie'}},
#  {'_id': '23644123', 'host': {'host_name': 'Daniel'}},
#  {'_id': '2515976', 'host': {'host_name': 'Frederico & Marcela'}},
#  {'_id': '25281601', 'host': {'host_name': 'Eric'}},
#  {'_id': '26471879', 'host': {'host_name': 'Jeff Yza'}},
#  {'_id': '2683147', 'host': {'host_name': 'Rodrigo Guandelini'}},
#  {'_id': '3800450', 'host': {'host_name': 'Carolina'}},
#  {'_id': '30792893', 'host': {'host_name': 'Kyle'}},
#  {'_id': '30950498', 'host': {'host_name': 'RioHost'}},
#  {'_id': '4081276', 'host': {'host_name': 'Daniel'}},
#  {'_id': '31191629', 'host': {'host_name': 'Aj'}},
#  {'_id': '31448135', 'host': {'host_name': 'San Lorenzo'}},
#  {'_id': '4451485', 'host': {'host_name': 'Yanick'}},
#  {'_id': '4467174', 'host': {'host_name': 'Kai'}},
#  {'_id': '8043869', 'host': {'host_name': 'Aracele'}},
#  {'_id': '890444', 'host': {'host_name': 'Valérie'}},
#  {'_id': '31984148', 'host': {'host_name': 'Claudio'}},
#  {'_id': '32025949', 'host': {'host_name': 'Liv MTL'}},
#  {'_id': '4688573', 'host': {'host_name': 'Ichraf'}},
#  {'_id': '4743645', 'host': {'host_name': 'Kosta & Denis'}},
#  {'_id': '3210248', 'host': {'host_name': 'Bruno'}},
#  {'_id': '32104281', 'host': {'host_name': 'William'}},
#  {'_id': '4790136', 'host': {'host_name': 'Beth'}},
#  {'_id': '9172046', 'host': {'host_name': 'Marcelo'}},
#  {'_id': '484267', 'host': {'host_name': 'Celia'}},
#  {'_id': '4987188', 'host': {'host_name': 'Vilma E Sidney'}},
#  {'_id': '32798068', 'host': {'host_name': 'Didi'}},
#  {'_id': '32806919', 'host': {'host_name': 'Ayleen'}},
#  {'_id': '32838638', 'host': {'host_name': 'Aj'}},
#  {'_id': '32839070', 'host': {'host_name': 'Ferum'}},
#  {'_id': '332150', 'host': {'host_name': 'Casa 48 Guesthouse'}},
#  {'_id': '926669', 'host': {'host_name': 'Renata'}},
#  {'_id': '9369576', 'host': {'host_name': 'Alexandre'}},
#  {'_id': '3448897', 'host': {'host_name': 'Jamil Alberto'}},
#  {'_id': '9643051', 'host': {'host_name': 'Ewa'}},
#  {'_id': '9789520', 'host': {'host_name': 'Franca'}},
#  {'_id': '5814254', 'host': {'host_name': 'Rachel'}},
#  {'_id': '359969', 'host': {'host_name': 'Marie'}},
#  {'_id': '6119840', 'host': {'host_name': 'Eric'}},
#  {'_id': '9987200', 'host': {'host_name': 'Dumont'}},
#  {'_id': '6185608', 'host': {'host_name': 'Marie-Andrée Et Stéphane'}},
#  {'_id': '6349210', 'host': {'host_name': 'Carlos'}},
#  {'_id': '654519', 'host': {'host_name': 'Marcos'}},
#  {'_id': '6589965', 'host': {'host_name': 'Richard'}},
#  {'_id': '664017', 'host': {'host_name': 'Mari'}},
#  {'_id': '4555069', 'host': {'host_name': 'Yann'}},
#  {'_id': '4621926', 'host': {'host_name': 'Maria'}},
#  {'_id': '4692378', 'host': {'host_name': 'François'}},
#  {'_id': '9524926', 'host': {'host_name': 'Alexandre'}},
#  {'_id': '490098', 'host': {'host_name': 'Renata'}},
#  {'_id': '4915245', 'host': {'host_name': 'Carlos'}},
#  {'_id': '4924343', 'host': {'host_name': 'Ricardo'}},
#  {'_id': '4964534', 'host': {'host_name': 'Pablo And Gloria'}},
#  {'_id': '5083829', 'host': {'host_name': 'Veronique'}},
#  {'_id': '5469770', 'host': {'host_name': 'Véro'}},
#  {'_id': '6457918', 'host': {'host_name': 'Philippe'}},
#  {'_id': '6670684', 'host': {'host_name': 'Joe'}},
#  {'_id': '6778993', 'host': {'host_name': 'Marilene'}},
#  {'_id': '746187', 'host': {'host_name': 'Silvia E Sidiney'}},
#  {'_id': '846689', 'host': {'host_name': 'Monica'}},
#  {'_id': '8634239', 'host': {'host_name': 'Richard'}},
#  {'_id': '880678', 'host': {'host_name': 'Paulo'}}]

# %%
# This doesn't work as expected!
coll.find_one({ 'amenities': "Internet" or "TV" })

# Why not? Consider the following:
print("Internet" or "TV")
